# %%
from mammoth import *

# %% [markdown]
# ## I will build time series data by myself

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

seq_len = 1000
x = np.arange(seq_len)

series_1 = (np.log2(np.arange(seq_len)+1)+2*np.arange(seq_len)**0.5+
            4*np.sin(0.2*(x+1))+5*np.cos(x+12)+7*np.cos(0.04*(x-8))+
            np.random.random(seq_len)*5.5)
series_1 = pd.DataFrame({'series_key':['series_1']*seq_len, 
                         'time_idx':x,
                         'y':series_1,
                         'sin_wx':np.sin(0.2*(x+1)),
                         'cos_wx':np.cos(x+12)})

series_2 = (0.0002*(np.arange(seq_len)-400)**2+40+
            7*np.sin(0.5*(x+1))+10*np.cos(0.1*x)-4*np.cos(0.9*(x-20))+20*np.sin(0.02*(x+4))+
            np.random.random(seq_len)*5)
series_2 = pd.DataFrame({'series_key':['series_2']*seq_len, 
                         'time_idx':x,
                         'y':series_2,
                         'sin_wx':np.sin(0.02*(x+4)),
                         'cos_wx':np.cos(0.9*(x-20))})

series_3 = (np.log2(200-10*np.arange(seq_len)**0.2)**3/10+
            3*np.sin(0.05*(x-9))+2*np.sin(0.01*x)-np.cos(8*(x-10))-3*np.sin(0.2*(x+40))+
            np.random.random(seq_len)*4)
series_3 = pd.DataFrame({'series_key':['series_3']*seq_len, 
                         'time_idx':x,
                         'y':series_3,
                         'sin_wx':np.sin(0.01*x),
                         'cos_wx':np.cos(8*(x-10))})

data = pd.concat([series_1, series_2, series_3], ignore_index=True)
data['key_embed'] = data['series_key'].copy()

# %%
plt.figure(figsize=(10,4), dpi=100)
for key in data['series_key'].unique():
    plt.plot(data[data['series_key']==key]['y'].values, label=key)
plt.legend()
plt.grid(alpha=0.3)
plt.title('self-made time series')
plt.show()

# %% [markdown]
# # Build dataset for training and forecasting
# ***
#
# <font size=4>**dsbuilder** is the function to generate dataset for train, validation and forecast.</font>
#
# ***
# <font size=3>***input_settings*** is a dictionary contains the basic settings for preprocessing.</font>
#
# Required keys for 'input_settings' are as follows:
#
# * `seq_key` $<List/string/integer>$ The primary key of time series.
# * `seq_label` $<List/string/integer>$ The columns to identity the time sequence, such as calendar date or cumulative number.
# * `seq_target` $<List/string/integer>$ The target to predict.
# * `perc_horizon` $<integer>$ The size of looking back window, which means how long of historical data you will refer to.
# * `fcst_horizon` $<integer>$ The prediction length.
#
# Alternative keys for 'input_settings' are as follows:
# * `enc_feat` $<List>$ The name of features used in the encoding part. default: [].
# * `dec_feat` $<List>$ The name of features used in the decoding part. default: [].
# * `embed_feat` $<List>$ The name of embedding features. default: [].
# * `norm_feat` $<dictionary>$ The features you want to normalize. It is recommended to define 'norm_feat' within 'single_tsm' function. When you define 'norm_feat' here, there won't be trainable weights on mean and standard deviation. default: {}.
# * `min_avail_perc_rate` $<float>$ The minimum rate of padding time points verus perception horizon. When exceeded, the data at that time point will be padded. default: 0.25.
# * `min_avail_seq_rate` $<float>$ The minimum rate of padding time points verus each time series. Exceeded time series won't be trained. default: 0.5.
# * `window_freq` $<integer>$ The strides of sliding window to get time series pieces. default: 1.
# * `val_rate` $<float>$ The rate of validation part in train data. If None, no validation data will be built. default: None
#
# ***
# <font size=3>***train_settings*** is a dictionary contains the basic settings for training.</font>
#
# Alternative settings are as follows:
#
# * `optimizer` The optimizer function. It can either be a function in 'tensorflow.keras.optimizers' or the string representing the function. For detail, please refer to tensorflow.keras tutorial. default: 'adam'.
# * `learning_rate` default: 0.01.
# * `loss_func` It can be a python func(refer to tensorflow.keras tutorial for how to build self-defined Loss Function or string. Also it can be any iterable object(e.g. 'list' or 'tuple') containing different losses(e.g. ['mae','mse']). default: 'mae'.
# * `loss_weights` Same parameter in 'tensorflow.keras.model.Model.compile'. default: None.
# * `weighted_metrics` Same parameter in 'tensorflow.keras.model.Model.compile'. default: ['mae', PearsonCoef].
# * `batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 16.
# * `epochs` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1000.
# * `callbacks` Same parameter in 'tensorflow.keras.model.Model.fit'. For detail in defining your own callback functino, please refer to 'tensorflow.keras.callbacks'. default: [EarlyStopping(monitor='loss', patience=10)].
# * `verbose` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `validation_steps` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_freq` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `use_multiprocessing` Same parameter in 'tensorflow.keras.model.Model.fit'. Note that: 'multiprocessing' is not available when used GPU numbers < 2 or tensorflow version < 2.5.0. default: True.
# * `shuffle` Same parameter in 'tensorflow.keras.model.Model.fit'. default: True.
#
# ***
# Callable Arguments:
# * `train_data` $<pandas.DataFrame>$ The dataframe used for training.
# * `fcst_data` $<pandas.DataFrame>$ The dataframe used for forecasting.
# * `embed_data` $<pandas.DataFrame>$ The dataframe used for embedding.
#
# ***
# Return:
# * `train_dataset` $<tensorflow.data.Dataset>$ Dataset for training.
# * `val_dataset` $<tensorflow.data.Dataset>$ Dataset for validation.
# * `fcst_dataset` $<tensorflow.data.Dataset>$ Dataset for forecasting.
# * `input_settings` $<dictionary>$ Updated input_settings.
# * `prediction` $<pandas.DataFrame>$ The primary key frame of forecast, including seq_key and seq_label.

# %%
from tensorflow.keras.callbacks import EarlyStopping
from mammoth.losses import PearsonCoef
tf_ignore_warnings() ## Ignore warnings

## define input_settings
input_settings = {'seq_key':['series_key'],
                  'seq_label':['time_idx'],
                  'seq_target':['y'],
                  'perc_horizon':128,'fcst_horizon':1,
                  'enc_feat':['sin_wx', 'cos_wx'], 
                  'dec_feat':['sin_wx', 'cos_wx'], 
                  'embed_feat':['key_embed'],
                  'val_rate':0.25, 'window_freq':1}

## define train_settings
train_settings = {'learning_rate':0.01, 'loss_func':'mae', 'batch_size':3,
                  'weighted_metrics':['mae',PearsonCoef],
                  'epochs':200, 'callbacks':[EarlyStopping(monitor='val_loss', patience=10)],
                  'use_multiprocessing':False}

train_data = data[data['time_idx']<=900]
fcst_data = data[data['time_idx']>900]
embed_data = data[input_settings['seq_key']+input_settings['embed_feat']].drop_duplicates()

## Use 'dsbuilder' to create datasets for training, validation and forecasting
train_dataset,\
val_dataset,\
fcst_dataset, \
input_settings, \
prediction = dsbuilder(input_settings)(train_data, fcst_data, embed_data)
# Out:
# /Users/diggerwang/Desktop/github/mammoth/mammoth/data_loader.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['_count_'] = 1

# %% [markdown]
# ## Build time series models
# ***
#
# <font size=4>**signle_tsm** is the function to generate single time series model.</font>
#
# ***
# <font size=3>**Arguments**</font>
#
# ***input_settings*** \
# See the tutourials above.
#
# ***train_settings*** \
# See the tutourials above.
#
# ***embedding*** \
# A dictionary whose key is the method of embedding, normally string type, and value is also a dictionary which contains the hyperparameter for embedding(e.g. {'SimpleEmbedding':{'n_embed_layers':2}}).
# The builtin embedding is called 'SimpleEmbedding'. For customized embedding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'SimpleEmbedding':{}}.
#
# ***encoder*** \
# A dictionary whose key is the method of time series encoding, normally string type, and value is also a dictionary which contains the hyperparameter for encoding(e.g. {'WavenetEncoder':{'n_enc_filters':8, 'n_enc_layers':6}}).
# There are 4 builtin encoding methods:
# * `WavenetEncoder` -> https://arxiv.org/pdf/1609.03499v2.pdf
# * `TransformerEncoder` -> https://arxiv.org/pdf/1706.03762v5.pdf
# * `InformerEncoder` -> https://arxiv.org/pdf/2012.07436v3.pdf
# * `SciEncoder` -> https://arxiv.org/pdf/2106.09305v3.pdf
#
# For customized encoding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'WavenetEncoder':{}}.
#
# ***decoder*** \
# A dictionary whose key is the method of time series decoding, normally string type, and value is also a dictionary which contains the hyperparameter for decoding(e.g. {'DenseDecoder':{'dec_activation':'elu'}}).
# There are 2 builtin decoding methods:
# * `DenseDecoder` -> The most common decoding methods. Using fully connected layers after the encoder part to get decoder part.
# * `CaCtDecoder` -> https://arxiv.org/pdf/1711.11053v2.pdf
#
# For customized decoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'DenseDecoder':{}}.
#
# ***recoder*** \
# A dictionary whose key is the method of time series reverse encoding, normally string type, and value is also a dictionary which contains the hyperparameter for reverse encoding(e.g. {'ConvRecoder':{'n_rec_layers':2}}). Reverse encoding is used in multi-horizon forecasting. When you have enough future information and use them as the latent features, you can reverse encode the future information to its relative past time points.
# There are 1 builtin reverse encoding method:
# * `ConvRecoder` -> Use convolution to encode future information to now reversely.
#
# For customized reverse encoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'ConvRecoder':{}}.
#
# ***output*** \
# A dictionary whose key is the method of output, normally string type, and value is also a dictionary which contains the hyperparameter for output(e.g. {'MlpOutput':{'mlp_dims':[16,8]}}).
# There are 3 builtin output methods:
# * `MlpOutput` -> The most common output methods. Just use several fully connected layers to get the final output.
# * `AttentionOutput` -> The attention mechanism applied on the feature dimension. Usually used in attention-related models, e.g. Informer.
# * `TabnetOutput` -> Using TabNet for the final regression or classification. For TabNet, please refer to https://arxiv.org/pdf/1908.07442v5.pdf.
#
# ***is_fork*** \
# Whether use fork training. Fork training is only available to RNN-based and RNN-based models, e.g. 'WaveNet' and 'SCINet'. Fork training can save memory and speed up training process.
#
# ***norm_feat*** \
# A dictionary whose key is the normalization methods, and value is a iterable object that contains features you want to normalize. e.g. {'standard':['f1', 'f2']}. There are 4 normalization methods:
# * `standard`: $\frac{x-avg(x)}{std(x)}$
# * `minmax`: $\frac{x-min(x)}{max(x)-min(x)}$
# * `mean`: $\frac{x}{avg(x)}$
# * `maxabs`: $\frac{x}{max(abs(x))}$
#
# Note that: the target will be normalized using `RevIN` automatically. Thus you don't need to declare the target in 'norm_feat'. For `RevIN`, please refer to https://openreview.net/pdf?id=cGDAkQo1C0p. default: None.
#
# ***perc_horizon*** \
# The length of looking back window. If None, it will be the same with that defined in 'input_settings'. If not None, the value will replace the original 'perc_horizon' defined in 'input_settings'. default: None.
#
# ***
# <font size=3>**Return**</font>
#
# The untrained model with object type `ModelBase`

# %%
## Here take 'Transformer' as an example

wavenet = single_tsm(input_settings, train_settings, 
                     embedding = {'SimpleEmbedding':{'embed_out_dim':2}}, 
                     encoder = {'WavenetEncoder':{'n_enc_filters':8, 
                                                   'n_enc_layers':7}}, 
                     decoder = {'DenseDecoder':{}}, 
                     recoder = None, 
                     output = {'MlpOutput':{'mlp_dims':[16,8]}},
                     norm_feat = {'maxabs':['sin_wx','cos_wx']},
                     perc_horizon = 128,
                     is_fork = True,
                     is_feat_affine = False)
wavenet.summary()
# Out:
# Model: "ts_model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 676, 3)]     0           []
#
#  input_17 (InputLayer)          [(None, 676, 1)]     0           []
#
#  TSInstanceNormalization_maxabs  (None, 676, 3)      0           ['input_16[0][0]',
#  _3 (TSInstanceNormalization)                                     'input_17[0][0]']
#
#  SplitHisFut_3 (SplitHisFut)    ((None, 675, 3),     0           ['TSInstanceNormalization_maxabs_
#                                  (None, 675, 1, 2),              3[0][0]',
#                                  (None, 675, 1),                  'input_17[0][0]']
#                                  (None, 675, 1, 1))
#
#  RevIN_3 (RevIN)                ((None, 675, 3),     2           ['SplitHisFut_3[0][0]',
#                                  (None, 1, 1),                    'SplitHisFut_3[0][2]']
#                                  (None, 1, 1))
#
#  encoder_input_multiply_masking  (None, 675, 3)      0           ['RevIN_3[0][0]',
#  _3 (Multiply)                                                    'SplitHisFut_3[0][2]']
#
#  WavenetEncoder_3 (WavenetEncod  (None, 675, 8)      872         ['encoder_input_multiply_masking_
#  er)                                                             3[0][0]']
#
#  input_18 (InputLayer)          [(None, 1)]          0           []
#
#  slice_encoder_output_3 (Lambda  (None, 675, 8)      0           ['WavenetEncoder_3[0][0]']
#  )
#
#  SimpleEmbedding_3 (SimpleEmbed  (None, 2)           2           ['input_18[0][0]']
#  ding)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 675, 1, 8)    0           ['slice_encoder_output_3[0][0]']
#
#  expand_embed_input_dims_3 (Res  (None, 1, 1, 2)     0           ['SimpleEmbedding_3[0][0]']
#  hape)
#
#  DenseDecoder_3 (DenseDecoder)  (None, 675, 1, 8)    1           ['tf.expand_dims_2[0][0]']
#
#  decoder_input_multiply_masking  (None, 675, 1, 2)   0           ['SplitHisFut_3[0][1]',
#  _3 (Multiply)                                                    'SplitHisFut_3[0][3]']
#
#  tf.tile_5 (TFOpLambda)         (None, 675, 1, 2)    0           ['expand_embed_input_dims_3[0][0]
#                                                                  ']
#
#  concat_all_decoder_feats_3 (Co  (None, 675, 1, 12)  0           ['DenseDecoder_3[0][0]',
#  ncatenate)                                                       'decoder_input_multiply_masking_
#                                                                  3[0][0]',
#                                                                   'tf.tile_5[0][0]']
#
#  outlayer_input_multiply_maskin  (None, 675, 1, 12)  0           ['concat_all_decoder_feats_3[0][0
#  g_3 (Multiply)                                                  ]',
#                                                                   'SplitHisFut_3[0][3]']
#
#  MlpOutput_3 (MlpOutput)        (None, 675, 1, 1)    352         ['outlayer_input_multiply_masking
#                                                                  _3[0][0]']
#
#  denormalize_5 (Denormalize)    (None, 675, 1, 1)    0           ['MlpOutput_3[0][0]',
#                                                                   'RevIN_3[0][1]',
#                                                                   'RevIN_3[0][2]']
#
#  output (Lambda)                (None, 675, 1, 1)    0           ['denormalize_5[0][0]']
#
#  ts_model_6 (TSModel)           (None, 225, 1, 1)    1229        []
#
# ==================================================================================================
# Total params: 2,458
# Trainable params: 1,229
# Non-trainable params: 1,229
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the time series model

# %%
wavenet.fit(train_dataset, val_dataset)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 339ms/step - loss: 9.1469 - mae: 10.1444 - PearsonCoef: -0.2590 - val_loss: 7.0390 - val_mae: 7.0390 - val_PearsonCoef: -0.0540
# Epoch 2/200
# 1/1 [==============================] - 0s 286ms/step - loss: 8.8806 - mae: 9.8491 - PearsonCoef: -0.0473 - val_loss: 7.0693 - val_mae: 7.0693 - val_PearsonCoef: 0.1218
# Epoch 3/200
# 1/1 [==============================] - 0s 287ms/step - loss: 8.6747 - mae: 9.6207 - PearsonCoef: 0.1482 - val_loss: 7.0545 - val_mae: 7.0545 - val_PearsonCoef: 0.2183
# Epoch 4/200
# 1/1 [==============================] - 0s 390ms/step - loss: 8.4884 - mae: 9.4141 - PearsonCoef: 0.2790 - val_loss: 6.9722 - val_mae: 6.9722 - val_PearsonCoef: 0.2855
# Epoch 5/200
# 1/1 [==============================] - 0s 337ms/step - loss: 8.2784 - mae: 9.1813 - PearsonCoef: 0.3717 - val_loss: 6.8185 - val_mae: 6.8185 - val_PearsonCoef: 0.3298
# Epoch 6/200
# 1/1 [==============================] - 0s 331ms/step - loss: 8.0017 - mae: 8.8744 - PearsonCoef: 0.4423 - val_loss: 6.5988 - val_mae: 6.5988 - val_PearsonCoef: 0.3433
# Epoch 7/200
# 1/1 [==============================] - 0s 290ms/step - loss: 7.5848 - mae: 8.4120 - PearsonCoef: 0.4978 - val_loss: 6.3269 - val_mae: 6.3269 - val_PearsonCoef: 0.3269
# Epoch 8/200
# 1/1 [==============================] - 0s 289ms/step - loss: 6.9566 - mae: 7.7152 - PearsonCoef: 0.5391 - val_loss: 6.2590 - val_mae: 6.2590 - val_PearsonCoef: 0.2983
# Epoch 9/200
# 1/1 [==============================] - 0s 291ms/step - loss: 6.3834 - mae: 7.0796 - PearsonCoef: 0.5630 - val_loss: 7.0192 - val_mae: 7.0192 - val_PearsonCoef: 0.2921
# Epoch 10/200
# 1/1 [==============================] - 0s 289ms/step - loss: 6.5411 - mae: 7.2545 - PearsonCoef: 0.5723 - val_loss: 6.8548 - val_mae: 6.8548 - val_PearsonCoef: 0.3217
# Epoch 11/200
# 1/1 [==============================] - 0s 298ms/step - loss: 6.2097 - mae: 6.8869 - PearsonCoef: 0.5876 - val_loss: 6.2783 - val_mae: 6.2783 - val_PearsonCoef: 0.3628
# Epoch 12/200
# 1/1 [==============================] - 0s 291ms/step - loss: 5.6526 - mae: 6.2691 - PearsonCoef: 0.6120 - val_loss: 5.8198 - val_mae: 5.8198 - val_PearsonCoef: 0.4096
# Epoch 13/200
# 1/1 [==============================] - 0s 301ms/step - loss: 5.4875 - mae: 6.0859 - PearsonCoef: 0.6361 - val_loss: 5.5746 - val_mae: 5.5746 - val_PearsonCoef: 0.4499
# Epoch 14/200
# 1/1 [==============================] - 0s 294ms/step - loss: 5.4099 - mae: 5.9999 - PearsonCoef: 0.6553 - val_loss: 5.4439 - val_mae: 5.4439 - val_PearsonCoef: 0.4858
# Epoch 15/200
# 1/1 [==============================] - 0s 296ms/step - loss: 5.1954 - mae: 5.7620 - PearsonCoef: 0.6705 - val_loss: 5.3097 - val_mae: 5.3097 - val_PearsonCoef: 0.5241
# Epoch 16/200
# 1/1 [==============================] - 0s 304ms/step - loss: 4.8841 - mae: 5.4167 - PearsonCoef: 0.6821 - val_loss: 5.1530 - val_mae: 5.1530 - val_PearsonCoef: 0.5572
# Epoch 17/200
# 1/1 [==============================] - 0s 296ms/step - loss: 4.7155 - mae: 5.2298 - PearsonCoef: 0.6910 - val_loss: 4.9389 - val_mae: 4.9389 - val_PearsonCoef: 0.5815
# Epoch 18/200
# 1/1 [==============================] - 0s 306ms/step - loss: 4.7308 - mae: 5.2467 - PearsonCoef: 0.7021 - val_loss: 4.7784 - val_mae: 4.7784 - val_PearsonCoef: 0.6086
# Epoch 19/200
# 1/1 [==============================] - 0s 292ms/step - loss: 4.5893 - mae: 5.0898 - PearsonCoef: 0.7154 - val_loss: 4.6366 - val_mae: 4.6366 - val_PearsonCoef: 0.6388
# Epoch 20/200
# 1/1 [==============================] - 0s 294ms/step - loss: 4.3076 - mae: 4.7773 - PearsonCoef: 0.7311 - val_loss: 4.4288 - val_mae: 4.4288 - val_PearsonCoef: 0.6673
# Epoch 21/200
# 1/1 [==============================] - 0s 295ms/step - loss: 4.1293 - mae: 4.5797 - PearsonCoef: 0.7450 - val_loss: 4.3567 - val_mae: 4.3567 - val_PearsonCoef: 0.6921
# Epoch 22/200
# 1/1 [==============================] - 0s 297ms/step - loss: 4.0445 - mae: 4.4856 - PearsonCoef: 0.7550 - val_loss: 4.2011 - val_mae: 4.2011 - val_PearsonCoef: 0.7121
# Epoch 23/200
# 1/1 [==============================] - 0s 304ms/step - loss: 3.8841 - mae: 4.3077 - PearsonCoef: 0.7633 - val_loss: 3.9452 - val_mae: 3.9452 - val_PearsonCoef: 0.7268
# Epoch 24/200
# 1/1 [==============================] - 0s 299ms/step - loss: 3.6605 - mae: 4.0596 - PearsonCoef: 0.7701 - val_loss: 3.9311 - val_mae: 3.9311 - val_PearsonCoef: 0.7371
# Epoch 25/200
# 1/1 [==============================] - 0s 295ms/step - loss: 3.5510 - mae: 3.9382 - PearsonCoef: 0.7738 - val_loss: 3.4923 - val_mae: 3.4923 - val_PearsonCoef: 0.7429
# Epoch 26/200
# 1/1 [==============================] - 0s 301ms/step - loss: 3.8198 - mae: 4.2364 - PearsonCoef: 0.7778 - val_loss: 4.4243 - val_mae: 4.4243 - val_PearsonCoef: 0.7529
# Epoch 27/200
# 1/1 [==============================] - 0s 298ms/step - loss: 3.9827 - mae: 4.4170 - PearsonCoef: 0.7819 - val_loss: 3.6137 - val_mae: 3.6137 - val_PearsonCoef: 0.7584
# Epoch 28/200
# 1/1 [==============================] - 0s 298ms/step - loss: 3.2348 - mae: 3.5876 - PearsonCoef: 0.7876 - val_loss: 3.3826 - val_mae: 3.3826 - val_PearsonCoef: 0.7588
# Epoch 29/200
# 1/1 [==============================] - 0s 296ms/step - loss: 3.6584 - mae: 4.0574 - PearsonCoef: 0.7868 - val_loss: 3.5413 - val_mae: 3.5413 - val_PearsonCoef: 0.7650
# Epoch 30/200
# 1/1 [==============================] - 0s 296ms/step - loss: 3.1674 - mae: 3.5129 - PearsonCoef: 0.7917 - val_loss: 4.1085 - val_mae: 4.1085 - val_PearsonCoef: 0.7665
# Epoch 31/200
# 1/1 [==============================] - 0s 299ms/step - loss: 3.4133 - mae: 3.7855 - PearsonCoef: 0.7923 - val_loss: 3.5129 - val_mae: 3.5129 - val_PearsonCoef: 0.7616
# Epoch 32/200
# 1/1 [==============================] - 0s 296ms/step - loss: 2.9622 - mae: 3.2852 - PearsonCoef: 0.7938 - val_loss: 3.1886 - val_mae: 3.1886 - val_PearsonCoef: 0.7516
# Epoch 33/200
# 1/1 [==============================] - 0s 298ms/step - loss: 3.2851 - mae: 3.6434 - PearsonCoef: 0.7930 - val_loss: 3.3555 - val_mae: 3.3555 - val_PearsonCoef: 0.7540
# Epoch 34/200
# 1/1 [==============================] - 0s 305ms/step - loss: 2.8510 - mae: 3.1619 - PearsonCoef: 0.7936 - val_loss: 3.9013 - val_mae: 3.9013 - val_PearsonCoef: 0.7587
# Epoch 35/200
# 1/1 [==============================] - 0s 304ms/step - loss: 3.1409 - mae: 3.4834 - PearsonCoef: 0.7932 - val_loss: 3.2397 - val_mae: 3.2397 - val_PearsonCoef: 0.7572
# Epoch 36/200
# 1/1 [==============================] - 0s 296ms/step - loss: 2.7127 - mae: 3.0086 - PearsonCoef: 0.7969 - val_loss: 3.1896 - val_mae: 3.1896 - val_PearsonCoef: 0.7569
# Epoch 37/200
# 1/1 [==============================] - 0s 280ms/step - loss: 2.9209 - mae: 3.2395 - PearsonCoef: 0.7982 - val_loss: 3.5102 - val_mae: 3.5102 - val_PearsonCoef: 0.7645
# Epoch 38/200
# 1/1 [==============================] - 0s 279ms/step - loss: 2.6886 - mae: 2.9819 - PearsonCoef: 0.8006 - val_loss: 3.6845 - val_mae: 3.6845 - val_PearsonCoef: 0.7671
# Epoch 39/200
# 1/1 [==============================] - 0s 276ms/step - loss: 2.7919 - mae: 3.0964 - PearsonCoef: 0.8022 - val_loss: 3.2013 - val_mae: 3.2013 - val_PearsonCoef: 0.7628
# Epoch 40/200
# 1/1 [==============================] - 0s 286ms/step - loss: 2.5986 - mae: 2.8820 - PearsonCoef: 0.8037 - val_loss: 3.1340 - val_mae: 3.1340 - val_PearsonCoef: 0.7639
# Epoch 41/200
# 1/1 [==============================] - 0s 275ms/step - loss: 2.6481 - mae: 2.9368 - PearsonCoef: 0.8054 - val_loss: 3.3347 - val_mae: 3.3347 - val_PearsonCoef: 0.7729
# Epoch 42/200
# 1/1 [==============================] - 0s 278ms/step - loss: 2.5236 - mae: 2.7988 - PearsonCoef: 0.8081 - val_loss: 3.2626 - val_mae: 3.2626 - val_PearsonCoef: 0.7799
# Epoch 43/200
# 1/1 [==============================] - 0s 276ms/step - loss: 2.4067 - mae: 2.6692 - PearsonCoef: 0.8107 - val_loss: 3.0055 - val_mae: 3.0055 - val_PearsonCoef: 0.7860
# Epoch 44/200
# 1/1 [==============================] - 0s 271ms/step - loss: 2.4785 - mae: 2.7488 - PearsonCoef: 0.8133 - val_loss: 3.1131 - val_mae: 3.1131 - val_PearsonCoef: 0.7932
# Epoch 45/200
# 1/1 [==============================] - 0s 271ms/step - loss: 2.3244 - mae: 2.5779 - PearsonCoef: 0.8153 - val_loss: 3.3143 - val_mae: 3.3143 - val_PearsonCoef: 0.7976
# Epoch 46/200
# 1/1 [==============================] - 0s 272ms/step - loss: 2.4003 - mae: 2.6621 - PearsonCoef: 0.8161 - val_loss: 2.9242 - val_mae: 2.9242 - val_PearsonCoef: 0.7994
# Epoch 47/200
# 1/1 [==============================] - 0s 283ms/step - loss: 2.2531 - mae: 2.4988 - PearsonCoef: 0.8188 - val_loss: 2.8617 - val_mae: 2.8617 - val_PearsonCoef: 0.8024
# Epoch 48/200
# 1/1 [==============================] - 0s 269ms/step - loss: 2.2713 - mae: 2.5190 - PearsonCoef: 0.8206 - val_loss: 3.1008 - val_mae: 3.1008 - val_PearsonCoef: 0.8077
# Epoch 49/200
# 1/1 [==============================] - 0s 270ms/step - loss: 2.2783 - mae: 2.5268 - PearsonCoef: 0.8217 - val_loss: 2.9154 - val_mae: 2.9154 - val_PearsonCoef: 0.8127
# Epoch 50/200
# 1/1 [==============================] - 0s 268ms/step - loss: 2.1443 - mae: 2.3782 - PearsonCoef: 0.8244 - val_loss: 2.8179 - val_mae: 2.8179 - val_PearsonCoef: 0.8170
# Epoch 51/200
# 1/1 [==============================] - 0s 300ms/step - loss: 2.1754 - mae: 2.4126 - PearsonCoef: 0.8266 - val_loss: 3.0181 - val_mae: 3.0181 - val_PearsonCoef: 0.8197
# Epoch 52/200
# 1/1 [==============================] - 0s 263ms/step - loss: 2.1206 - mae: 2.3519 - PearsonCoef: 0.8278 - val_loss: 2.7970 - val_mae: 2.7970 - val_PearsonCoef: 0.8211
# Epoch 53/200
# 1/1 [==============================] - 0s 267ms/step - loss: 2.0407 - mae: 2.2632 - PearsonCoef: 0.8297 - val_loss: 2.7326 - val_mae: 2.7326 - val_PearsonCoef: 0.8233
# Epoch 54/200
# 1/1 [==============================] - 0s 272ms/step - loss: 2.0307 - mae: 2.2521 - PearsonCoef: 0.8312 - val_loss: 2.8828 - val_mae: 2.8828 - val_PearsonCoef: 0.8276
# Epoch 55/200
# 1/1 [==============================] - 0s 270ms/step - loss: 2.0331 - mae: 2.2548 - PearsonCoef: 0.8326 - val_loss: 2.6546 - val_mae: 2.6546 - val_PearsonCoef: 0.8334
# Epoch 56/200
# 1/1 [==============================] - 0s 273ms/step - loss: 2.0118 - mae: 2.2313 - PearsonCoef: 0.8360 - val_loss: 2.8135 - val_mae: 2.8135 - val_PearsonCoef: 0.8378
# Epoch 57/200
# 1/1 [==============================] - 0s 273ms/step - loss: 1.9500 - mae: 2.1626 - PearsonCoef: 0.8378 - val_loss: 2.7410 - val_mae: 2.7410 - val_PearsonCoef: 0.8404
# Epoch 58/200
# 1/1 [==============================] - 0s 274ms/step - loss: 1.9137 - mae: 2.1224 - PearsonCoef: 0.8401 - val_loss: 2.5816 - val_mae: 2.5816 - val_PearsonCoef: 0.8431
# Epoch 59/200
# 1/1 [==============================] - 0s 271ms/step - loss: 1.9432 - mae: 2.1551 - PearsonCoef: 0.8429 - val_loss: 2.8401 - val_mae: 2.8401 - val_PearsonCoef: 0.8468
# Epoch 60/200
# 1/1 [==============================] - 0s 278ms/step - loss: 2.0054 - mae: 2.2241 - PearsonCoef: 0.8446 - val_loss: 2.5188 - val_mae: 2.5188 - val_PearsonCoef: 0.8516
# Epoch 61/200
# 1/1 [==============================] - 0s 269ms/step - loss: 2.2139 - mae: 2.4553 - PearsonCoef: 0.8485 - val_loss: 3.0707 - val_mae: 3.0707 - val_PearsonCoef: 0.8534
# Epoch 62/200
# 1/1 [==============================] - 0s 268ms/step - loss: 2.2240 - mae: 2.4665 - PearsonCoef: 0.8487 - val_loss: 2.5015 - val_mae: 2.5015 - val_PearsonCoef: 0.8568
# Epoch 63/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.9853 - mae: 2.2019 - PearsonCoef: 0.8521 - val_loss: 2.6043 - val_mae: 2.6043 - val_PearsonCoef: 0.8568
# Epoch 64/200
# 1/1 [==============================] - 0s 306ms/step - loss: 1.7971 - mae: 1.9930 - PearsonCoef: 0.8529 - val_loss: 2.7749 - val_mae: 2.7749 - val_PearsonCoef: 0.8566
# Epoch 65/200
# 1/1 [==============================] - 0s 268ms/step - loss: 1.9496 - mae: 2.1622 - PearsonCoef: 0.8529 - val_loss: 2.5117 - val_mae: 2.5117 - val_PearsonCoef: 0.8588
# Epoch 66/200
# 1/1 [==============================] - 0s 276ms/step - loss: 2.1602 - mae: 2.3958 - PearsonCoef: 0.8542 - val_loss: 2.6865 - val_mae: 2.6865 - val_PearsonCoef: 0.8631
# Epoch 67/200
# 1/1 [==============================] - 0s 268ms/step - loss: 1.8397 - mae: 2.0403 - PearsonCoef: 0.8558 - val_loss: 2.6081 - val_mae: 2.6081 - val_PearsonCoef: 0.8680
# Epoch 68/200
# 1/1 [==============================] - 0s 275ms/step - loss: 1.7617 - mae: 1.9538 - PearsonCoef: 0.8578 - val_loss: 2.4218 - val_mae: 2.4218 - val_PearsonCoef: 0.8713
# Epoch 69/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.9024 - mae: 2.1098 - PearsonCoef: 0.8591 - val_loss: 2.6452 - val_mae: 2.6452 - val_PearsonCoef: 0.8734
# Epoch 70/200
# 1/1 [==============================] - 0s 273ms/step - loss: 1.8025 - mae: 1.9991 - PearsonCoef: 0.8603 - val_loss: 2.3933 - val_mae: 2.3933 - val_PearsonCoef: 0.8751
# Epoch 71/200
# 1/1 [==============================] - 0s 272ms/step - loss: 1.7209 - mae: 1.9085 - PearsonCoef: 0.8617 - val_loss: 2.4026 - val_mae: 2.4026 - val_PearsonCoef: 0.8772
# Epoch 72/200
# 1/1 [==============================] - 0s 279ms/step - loss: 1.6890 - mae: 1.8732 - PearsonCoef: 0.8630 - val_loss: 2.5244 - val_mae: 2.5244 - val_PearsonCoef: 0.8798
# Epoch 73/200
# 1/1 [==============================] - 0s 275ms/step - loss: 1.7130 - mae: 1.8999 - PearsonCoef: 0.8645 - val_loss: 2.3421 - val_mae: 2.3421 - val_PearsonCoef: 0.8826
# Epoch 74/200
# 1/1 [==============================] - 0s 269ms/step - loss: 1.7677 - mae: 1.9605 - PearsonCoef: 0.8656 - val_loss: 2.5332 - val_mae: 2.5332 - val_PearsonCoef: 0.8843
# Epoch 75/200
# 1/1 [==============================] - 0s 269ms/step - loss: 1.6984 - mae: 1.8836 - PearsonCoef: 0.8671 - val_loss: 2.3697 - val_mae: 2.3697 - val_PearsonCoef: 0.8858
# Epoch 76/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.6392 - mae: 1.8180 - PearsonCoef: 0.8680 - val_loss: 2.3377 - val_mae: 2.3377 - val_PearsonCoef: 0.8867
# Epoch 77/200
# 1/1 [==============================] - 0s 279ms/step - loss: 1.6339 - mae: 1.8121 - PearsonCoef: 0.8688 - val_loss: 2.4783 - val_mae: 2.4783 - val_PearsonCoef: 0.8884
# Epoch 78/200
# 1/1 [==============================] - 0s 269ms/step - loss: 1.6871 - mae: 1.8711 - PearsonCoef: 0.8700 - val_loss: 2.2975 - val_mae: 2.2975 - val_PearsonCoef: 0.8912
# Epoch 79/200
# 1/1 [==============================] - 0s 277ms/step - loss: 1.8265 - mae: 2.0257 - PearsonCoef: 0.8699 - val_loss: 2.6135 - val_mae: 2.6135 - val_PearsonCoef: 0.8926
# Epoch 80/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.7913 - mae: 1.9866 - PearsonCoef: 0.8716 - val_loss: 2.2839 - val_mae: 2.2839 - val_PearsonCoef: 0.8940
# Epoch 81/200
# 1/1 [==============================] - 0s 309ms/step - loss: 1.6622 - mae: 1.8435 - PearsonCoef: 0.8714 - val_loss: 2.3385 - val_mae: 2.3385 - val_PearsonCoef: 0.8941
# Epoch 82/200
# 1/1 [==============================] - 0s 274ms/step - loss: 1.5642 - mae: 1.7348 - PearsonCoef: 0.8722 - val_loss: 2.3795 - val_mae: 2.3795 - val_PearsonCoef: 0.8942
# Epoch 83/200
# 1/1 [==============================] - 0s 273ms/step - loss: 1.5927 - mae: 1.7664 - PearsonCoef: 0.8726 - val_loss: 2.2439 - val_mae: 2.2439 - val_PearsonCoef: 0.8953
# Epoch 84/200
# 1/1 [==============================] - 0s 280ms/step - loss: 1.6833 - mae: 1.8668 - PearsonCoef: 0.8723 - val_loss: 2.5033 - val_mae: 2.5033 - val_PearsonCoef: 0.8970
# Epoch 85/200
# 1/1 [==============================] - 0s 271ms/step - loss: 1.6962 - mae: 1.8812 - PearsonCoef: 0.8740 - val_loss: 2.2483 - val_mae: 2.2483 - val_PearsonCoef: 0.8993
# Epoch 86/200
# 1/1 [==============================] - 0s 271ms/step - loss: 1.6228 - mae: 1.7998 - PearsonCoef: 0.8735 - val_loss: 2.3462 - val_mae: 2.3462 - val_PearsonCoef: 0.8999
# Epoch 87/200
# 1/1 [==============================] - 0s 270ms/step - loss: 1.5346 - mae: 1.7019 - PearsonCoef: 0.8748 - val_loss: 2.3130 - val_mae: 2.3130 - val_PearsonCoef: 0.8998
# Epoch 88/200
# 1/1 [==============================] - 0s 272ms/step - loss: 1.5184 - mae: 1.6840 - PearsonCoef: 0.8754 - val_loss: 2.2218 - val_mae: 2.2218 - val_PearsonCoef: 0.9000
# Epoch 89/200
# 1/1 [==============================] - 0s 276ms/step - loss: 1.5666 - mae: 1.7375 - PearsonCoef: 0.8752 - val_loss: 2.3849 - val_mae: 2.3849 - val_PearsonCoef: 0.9012
# Epoch 90/200
# 1/1 [==============================] - 0s 280ms/step - loss: 1.5931 - mae: 1.7669 - PearsonCoef: 0.8767 - val_loss: 2.2175 - val_mae: 2.2175 - val_PearsonCoef: 0.9030
# Epoch 91/200
# 1/1 [==============================] - 0s 270ms/step - loss: 1.6333 - mae: 1.8114 - PearsonCoef: 0.8756 - val_loss: 2.4004 - val_mae: 2.4004 - val_PearsonCoef: 0.9038
# Epoch 92/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.5654 - mae: 1.7361 - PearsonCoef: 0.8773 - val_loss: 2.2241 - val_mae: 2.2241 - val_PearsonCoef: 0.9036
# Epoch 93/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.4964 - mae: 1.6596 - PearsonCoef: 0.8766 - val_loss: 2.2307 - val_mae: 2.2307 - val_PearsonCoef: 0.9029
# Epoch 94/200
# 1/1 [==============================] - 0s 276ms/step - loss: 1.4736 - mae: 1.6343 - PearsonCoef: 0.8771 - val_loss: 2.2728 - val_mae: 2.2728 - val_PearsonCoef: 0.9033
# Epoch 95/200
# 1/1 [==============================] - 0s 272ms/step - loss: 1.4879 - mae: 1.6502 - PearsonCoef: 0.8775 - val_loss: 2.1919 - val_mae: 2.1919 - val_PearsonCoef: 0.9049
# Epoch 96/200
# 1/1 [==============================] - 0s 273ms/step - loss: 1.5283 - mae: 1.6950 - PearsonCoef: 0.8766 - val_loss: 2.4290 - val_mae: 2.4290 - val_PearsonCoef: 0.9061
# Epoch 97/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.5839 - mae: 1.7566 - PearsonCoef: 0.8783 - val_loss: 2.1900 - val_mae: 2.1900 - val_PearsonCoef: 0.9067
# Epoch 98/200
# 1/1 [==============================] - 0s 267ms/step - loss: 1.5446 - mae: 1.7130 - PearsonCoef: 0.8768 - val_loss: 2.3163 - val_mae: 2.3163 - val_PearsonCoef: 0.9065
# Epoch 99/200
# 1/1 [==============================] - 0s 270ms/step - loss: 1.4898 - mae: 1.6523 - PearsonCoef: 0.8786 - val_loss: 2.1788 - val_mae: 2.1788 - val_PearsonCoef: 0.9067
# Epoch 100/200
# 1/1 [==============================] - 0s 271ms/step - loss: 1.4911 - mae: 1.6538 - PearsonCoef: 0.8777 - val_loss: 2.3119 - val_mae: 2.3119 - val_PearsonCoef: 0.9077
# Epoch 101/200
# 1/1 [==============================] - 0s 280ms/step - loss: 1.4783 - mae: 1.6395 - PearsonCoef: 0.8791 - val_loss: 2.1846 - val_mae: 2.1846 - val_PearsonCoef: 0.9085
# Epoch 102/200
# 1/1 [==============================] - 0s 268ms/step - loss: 1.5093 - mae: 1.6739 - PearsonCoef: 0.8779 - val_loss: 2.3913 - val_mae: 2.3913 - val_PearsonCoef: 0.9090
# Epoch 103/200
# 1/1 [==============================] - 0s 273ms/step - loss: 1.5224 - mae: 1.6884 - PearsonCoef: 0.8796 - val_loss: 2.1836 - val_mae: 2.1836 - val_PearsonCoef: 0.9082
# Epoch 104/200
# 1/1 [==============================] - 0s 275ms/step - loss: 1.5221 - mae: 1.6881 - PearsonCoef: 0.8781 - val_loss: 2.3262 - val_mae: 2.3262 - val_PearsonCoef: 0.9080
# Epoch 105/200
# 1/1 [==============================] - 0s 265ms/step - loss: 1.4754 - mae: 1.6363 - PearsonCoef: 0.8797 - val_loss: 2.1860 - val_mae: 2.1860 - val_PearsonCoef: 0.9079
# Epoch 106/200
# 1/1 [==============================] - 0s 282ms/step - loss: 1.4575 - mae: 1.6165 - PearsonCoef: 0.8785 - val_loss: 2.3005 - val_mae: 2.3005 - val_PearsonCoef: 0.9089
# Epoch 107/200
# 1/1 [==============================] - 0s 268ms/step - loss: 1.4251 - mae: 1.5805 - PearsonCoef: 0.8795 - val_loss: 2.2060 - val_mae: 2.2060 - val_PearsonCoef: 0.9094
# Epoch 108/200
# 1/1 [==============================] - 0s 282ms/step - loss: 1.4150 - mae: 1.5693 - PearsonCoef: 0.8786 - val_loss: 2.2722 - val_mae: 2.2722 - val_PearsonCoef: 0.9093
# Epoch 109/200
# 1/1 [==============================] - 0s 274ms/step - loss: 1.3974 - mae: 1.5498 - PearsonCoef: 0.8794 - val_loss: 2.2055 - val_mae: 2.2055 - val_PearsonCoef: 0.9089

# %% [markdown]
# ## Forecast based on fitted model
# ***
#
# <font size=3>There are two forecasting modes: </font>
#
# 1. `multi-horizon` is used when 'fcst_horizon' defined in 'input_settings' is equal to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset)` to get the prediction.
#
# 2. `rolling` is used when 'fcst_horizon' defined in 'input_settings' is smaller to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset, rolling=True)` to get the prediction.

# %%
prediction['pred'] = wavenet.predict(fcst_dataset, rolling=True).flatten()
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f7824f2fe60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step

# %%
## Check the prediction accuracy
for key in data['series_key'].unique():
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(data[data['series_key']==key]['time_idx'],
             data[data['series_key']==key]['y'], label='Actual')
    plt.plot(prediction[prediction['series_key']==key]['time_idx'],
             prediction[prediction['series_key']==key]['pred'], label='Prediction')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.title(key)
    plt.show()
