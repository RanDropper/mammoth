# %%
from mammoth import *

# %% [markdown]
# ## I will build time series data by myself

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

seq_len = 1000
x = np.arange(seq_len)

series_1 = (np.log2(np.arange(seq_len)+1)+2*np.arange(seq_len)**0.5+
            4*np.sin(0.2*(x+1))+5*np.cos(x+12)+7*np.cos(0.04*(x-8))+
            np.random.random(seq_len)*5.5)
series_1 = pd.DataFrame({'series_key':['series_1']*seq_len, 
                         'time_idx':x,
                         'y':series_1,
                         'sin_wx':np.sin(0.2*(x+1)),
                         'cos_wx':np.cos(x+12)})

series_2 = (0.0002*(np.arange(seq_len)-400)**2+40+
            7*np.sin(0.5*(x+1))+10*np.cos(0.1*x)-4*np.cos(0.9*(x-20))+20*np.sin(0.02*(x+4))+
            np.random.random(seq_len)*5)
series_2 = pd.DataFrame({'series_key':['series_2']*seq_len, 
                         'time_idx':x,
                         'y':series_2,
                         'sin_wx':np.sin(0.02*(x+4)),
                         'cos_wx':np.cos(0.9*(x-20))})

series_3 = (np.log2(200-10*np.arange(seq_len)**0.2)**3/10+
            3*np.sin(0.05*(x-9))+2*np.sin(0.01*x)-np.cos(8*(x-10))-3*np.sin(0.2*(x+40))+
            np.random.random(seq_len)*4)
series_3 = pd.DataFrame({'series_key':['series_3']*seq_len, 
                         'time_idx':x,
                         'y':series_3,
                         'sin_wx':np.sin(0.01*x),
                         'cos_wx':np.cos(8*(x-10))})

data = pd.concat([series_1, series_2, series_3], ignore_index=True)
data['key_embed'] = data['series_key'].copy()

# %%
plt.figure(figsize=(10,4), dpi=100)
for key in data['series_key'].unique():
    plt.plot(data[data['series_key']==key]['y'].values, label=key)
plt.legend()
plt.grid(alpha=0.3)
plt.title('self-made time series')
plt.show()

# %% [markdown]
# # Build dataset for training and forecasting
# ***
#
# <font size=4>**dsbuilder** is the function to generate dataset for train, validation and forecast.</font>
#
# ***
# <font size=3>***input_settings*** is a dictionary contains the basic settings for preprocessing.</font>
#
# Required keys for 'input_settings' are as follows:
#
# * `seq_key` $<List/string/integer>$ The primary key of time series.
# * `seq_label` $<List/string/integer>$ The columns to identity the time sequence, such as calendar date or cumulative number.
# * `seq_target` $<List/string/integer>$ The target to predict.
# * `perc_horizon` $<integer>$ The size of looking back window, which means how long of historical data you will refer to.
# * `fcst_horizon` $<integer>$ The prediction length.
#
# Alternative keys for 'input_settings' are as follows:
# * `enc_feat` $<List>$ The name of features used in the encoding part. default: [].
# * `dec_feat` $<List>$ The name of features used in the decoding part. default: [].
# * `embed_feat` $<List>$ The name of embedding features. default: [].
# * `norm_feat` $<dictionary>$ The features you want to normalize. It is recommended to define 'norm_feat' within 'single_tsm' function. When you define 'norm_feat' here, there won't be trainable weights on mean and standard deviation. default: {}.
# * `min_avail_perc_rate` $<float>$ The minimum rate of padding time points verus perception horizon. When exceeded, the data at that time point will be padded. default: 0.25.
# * `min_avail_seq_rate` $<float>$ The minimum rate of padding time points verus each time series. Exceeded time series won't be trained. default: 0.5.
# * `window_freq` $<integer>$ The strides of sliding window to get time series pieces. default: 1.
# * `val_rate` $<float>$ The rate of validation part in train data. If None, no validation data will be built. default: None
#
# ***
# <font size=3>***train_settings*** is a dictionary contains the basic settings for training.</font>
#
# Alternative settings are as follows:
#
# * `optimizer` The optimizer function. It can either be a function in 'tensorflow.keras.optimizers' or the string representing the function. For detail, please refer to tensorflow.keras tutorial. default: 'adam'.
# * `learning_rate` default: 0.01.
# * `loss_func` It can be a python func(refer to tensorflow.keras tutorial for how to build self-defined Loss Function or string. Also it can be any iterable object(e.g. 'list' or 'tuple') containing different losses(e.g. ['mae','mse']). default: 'mae'.
# * `loss_weights` Same parameter in 'tensorflow.keras.model.Model.compile'. default: None.
# * `weighted_metrics` Same parameter in 'tensorflow.keras.model.Model.compile'. default: ['mae', PearsonCoef].
# * `batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 16.
# * `epochs` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1000.
# * `callbacks` Same parameter in 'tensorflow.keras.model.Model.fit'. For detail in defining your own callback functino, please refer to 'tensorflow.keras.callbacks'. default: [EarlyStopping(monitor='loss', patience=10)].
# * `verbose` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `validation_steps` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_freq` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `use_multiprocessing` Same parameter in 'tensorflow.keras.model.Model.fit'. Note that: 'multiprocessing' is not available when used GPU numbers < 2 or tensorflow version < 2.5.0. default: True.
# * `shuffle` Same parameter in 'tensorflow.keras.model.Model.fit'. default: True.
#
# ***
# Callable Arguments:
# * `train_data` $<pandas.DataFrame>$ The dataframe used for training.
# * `fcst_data` $<pandas.DataFrame>$ The dataframe used for forecasting.
# * `embed_data` $<pandas.DataFrame>$ The dataframe used for embedding.
#
# ***
# Return:
# * `train_dataset` $<tensorflow.data.Dataset>$ Dataset for training.
# * `val_dataset` $<tensorflow.data.Dataset>$ Dataset for validation.
# * `fcst_dataset` $<tensorflow.data.Dataset>$ Dataset for forecasting.
# * `input_settings` $<dictionary>$ Updated input_settings.
# * `prediction` $<pandas.DataFrame>$ The primary key frame of forecast, including seq_key and seq_label.

# %%
from tensorflow.keras.callbacks import EarlyStopping
from mammoth.losses import PearsonCoef
tf_ignore_warnings() ## Ignore warnings

## define input_settings
input_settings = {'seq_key':['series_key'],
                  'seq_label':['time_idx'],
                  'seq_target':['y'],
                  'perc_horizon':128,'fcst_horizon':1,
                  'enc_feat':['sin_wx', 'cos_wx'], 
                  'dec_feat':['sin_wx', 'cos_wx'], 
                  'embed_feat':['key_embed'], 'window_freq':1, 
                  'val_rate':0.2}

## define train_settings
train_settings = {'learning_rate':0.01, 'loss_func':'mae', 'batch_size':3,
                  'weighted_metrics':['mae',PearsonCoef],
                  'epochs':200, 'callbacks':[EarlyStopping(monitor='val_loss', patience=10)],
                  'use_multiprocessing':False,
                  'error_bound':{'ema_decay':0.99, 'epsilon':1, 'loss_threshold':3}}

train_data = data[data['time_idx']<=900]
fcst_data = data[data['time_idx']>900]
embed_data = data[input_settings['seq_key']+input_settings['embed_feat']].drop_duplicates()

## Use 'dsbuilder' to create datasets for training, validation and forecasting
train_dataset,\
val_dataset,\
fcst_dataset, \
input_settings, \
prediction = dsbuilder(input_settings)(train_data, fcst_data, embed_data)

# %% [markdown]
# ## Build time series models
# ***
#
# <font size=4>**signle_tsm** is the function to generate single time series model.</font>
#
# ***
# <font size=3>**Arguments**</font>
#
# ***input_settings*** \
# See the tutourials above.
#
# ***train_settings*** \
# See the tutourials above.
#
# ***embedding*** \
# A dictionary whose key is the method of embedding, normally string type, and value is also a dictionary which contains the hyperparameter for embedding(e.g. {'SimpleEmbedding':{'n_embed_layers':2}}).
# The builtin embedding is called 'SimpleEmbedding'. For customized embedding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'SimpleEmbedding':{}}.
#
# ***encoder*** \
# A dictionary whose key is the method of time series encoding, normally string type, and value is also a dictionary which contains the hyperparameter for encoding(e.g. {'WavenetEncoder':{'n_enc_filters':8, 'n_enc_layers':6}}).
# There are 4 builtin encoding methods:
# * `WavenetEncoder` -> https://arxiv.org/pdf/1609.03499v2.pdf
# * `TransformerEncoder` -> https://arxiv.org/pdf/1706.03762v5.pdf
# * `InformerEncoder` -> https://arxiv.org/pdf/2012.07436v3.pdf
# * `SciEncoder` -> https://arxiv.org/pdf/2106.09305v3.pdf
#
# For customized encoding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'WavenetEncoder':{}}.
#
# ***decoder*** \
# A dictionary whose key is the method of time series decoding, normally string type, and value is also a dictionary which contains the hyperparameter for decoding(e.g. {'DenseDecoder':{'dec_activation':'elu'}}).
# There are 2 builtin decoding methods:
# * `DenseDecoder` -> The most common decoding methods. Using fully connected layers after the encoder part to get decoder part.
# * `CaCtDecoder` -> https://arxiv.org/pdf/1711.11053v2.pdf
#
# For customized decoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'DenseDecoder':{}}.
#
# ***recoder*** \
# A dictionary whose key is the method of time series reverse encoding, normally string type, and value is also a dictionary which contains the hyperparameter for reverse encoding(e.g. {'ConvRecoder':{'n_rec_layers':2}}). Reverse encoding is used in multi-horizon forecasting. When you have enough future information and use them as the latent features, you can reverse encode the future information to its relative past time points.
# There are 1 builtin reverse encoding method:
# * `ConvRecoder` -> Use convolution to encode future information to now reversely.
#
# For customized reverse encoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'ConvRecoder':{}}.
#
# ***output*** \
# A dictionary whose key is the method of output, normally string type, and value is also a dictionary which contains the hyperparameter for output(e.g. {'MlpOutput':{'mlp_dims':[16,8]}}).
# There are 3 builtin output methods:
# * `MlpOutput` -> The most common output methods. Just use several fully connected layers to get the final output.
# * `AttentionOutput` -> The attention mechanism applied on the feature dimension. Usually used in attention-related models, e.g. Informer.
# * `TabnetOutput` -> Using TabNet for the final regression or classification. For TabNet, please refer to https://arxiv.org/pdf/1908.07442v5.pdf.
#
# ***is_fork*** \
# Whether use fork training. Fork training is only available to RNN-based and RNN-based models, e.g. 'WaveNet' and 'SCINet'. Fork training can save memory and speed up training process.
#
# ***norm_feat*** \
# A dictionary whose key is the normalization methods, and value is a iterable object that contains features you want to normalize. e.g. {'standard':['f1', 'f2']}. There are 4 normalization methods:
# * `standard`: $\frac{x-avg(x)}{std(x)}$
# * `minmax`: $\frac{x-min(x)}{max(x)-min(x)}$
# * `mean`: $\frac{x}{avg(x)}$
# * `maxabs`: $\frac{x}{max(abs(x))}$
#
# Note that: the target will be normalized using `RevIN` automatically. Thus you don't need to declare the target in 'norm_feat'. For `RevIN`, please refer to https://openreview.net/pdf?id=cGDAkQo1C0p. default: None.
#
# ***perc_horizon*** \
# The length of looking back window. If None, it will be the same with that defined in 'input_settings'. If not None, the value will replace the original 'perc_horizon' defined in 'input_settings'. default: None.
#
# ***
# <font size=3>**Return**</font>
#
# The untrained model with object type `ModelBase`

# %%
## Here take 'MTS-Mixer' as an example

timesnet = single_tsm(input_settings, train_settings, 
                     embedding = {'FactorizedEmbedding':{'embed_out_dim':2}}, 
                     encoder = {'TimesEncoder':{'n_enc_layers':3,
                                                'nfreq':4,
                                                'n_enc_filters':16,
                                                'enc_kernel_size':(4,4)}}, 
                     decoder = {'DenseDecoder':{}}, 
                     recoder = None, 
                     output = {'MlpOutput':{'mlp_dims':[16,8]}},
                     norm_feat = {'maxabs':['sin_wx','cos_wx']},
                     perc_horizon = 128,
                     is_feat_affine = False)
timesnet.summary()
# Out:
# Model: "ts_model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 721, 3)]     0           []
#
#  input_5 (InputLayer)           [(None, 721, 1)]     0           []
#
#  MovingWindowTransform_2 (Movin  ((None, 720, 129, 3  0          ['input_4[0][0]',
#  gWindowTransform)              ),                                'input_5[0][0]']
#                                  (None, 720, 129, 1
#                                 ))
#
#  TSInstanceNormalization_maxabs  (None, 720, 129, 3)  0          ['MovingWindowTransform_2[0][0]',
#  _2 (TSInstanceNormalization)                                     'MovingWindowTransform_2[0][1]']
#
#  SplitHisFut_2 (SplitHisFut)    ((None, 720, 128, 3  0           ['TSInstanceNormalization_maxabs_
#                                 ),                               2[0][0]',
#                                  (None, 720, 1, 2),               'MovingWindowTransform_2[0][1]']
#                                  (None, 720, 128, 1
#                                 ),
#                                  (None, 720, 1, 1))
#
#  RevIN_2 (RevIN)                ((None, 720, 128, 3  2           ['SplitHisFut_2[0][0]',
#                                 ),                                'SplitHisFut_2[0][2]']
#                                  (None, 720, 1, 1),
#                                  (None, 720, 1, 1))
#
#  encoder_input_multiply_masking  (None, 720, 128, 3)  0          ['RevIN_2[0][0]',
#  _2 (Multiply)                                                    'SplitHisFut_2[0][2]']
#
#  input_6 (InputLayer)           [(None, 1)]          0           []
#
#  TimesEncoder_2 (TimesEncoder)  (None, 720, 128, 16  12480       ['encoder_input_multiply_masking_
#                                 )                                2[0][0]']
#
#  FactorizedEmbedding_2 (Factori  (None, 2)           11          ['input_6[0][0]']
#  zedEmbedding)
#
#  slice_encoder_output_2 (Lambda  (None, 720, 128, 16  0          ['TimesEncoder_2[0][0]']
#  )                              )
#
#  expand_embed_input_dims_2 (Res  (None, 1, 1, 2)     0           ['FactorizedEmbedding_2[0][0]']
#  hape)
#
#  DenseDecoder_2 (DenseDecoder)  (None, 720, 1, 16)   128         ['slice_encoder_output_2[0][0]']
#
#  decoder_input_multiply_masking  (None, 720, 1, 2)   0           ['SplitHisFut_2[0][1]',
#  _2 (Multiply)                                                    'SplitHisFut_2[0][3]']
#
#  tf.tile_1 (TFOpLambda)         (None, 720, 1, 2)    0           ['expand_embed_input_dims_2[0][0]
#                                                                  ']
#
#  concat_all_decoder_feats_2 (Co  (None, 720, 1, 20)  0           ['DenseDecoder_2[0][0]',
#  ncatenate)                                                       'decoder_input_multiply_masking_
#                                                                  2[0][0]',
#                                                                   'tf.tile_1[0][0]']
#
#  outlayer_input_multiply_maskin  (None, 720, 1, 20)  0           ['concat_all_decoder_feats_2[0][0
#  g_2 (Multiply)                                                  ]',
#                                                                   'SplitHisFut_2[0][3]']
#
#  MlpOutput_2 (MlpOutput)        (None, 720, 1, 1)    480         ['outlayer_input_multiply_masking
#                                                                  _2[0][0]']
#
#  denormalize_1 (Denormalize)    (None, 720, 1, 1)    0           ['MlpOutput_2[0][0]',
#                                                                   'RevIN_2[0][1]',
#                                                                   'RevIN_2[0][2]']
#
#  output (Lambda)                (None, 720, 1, 1)    0           ['denormalize_1[0][0]']
#
#  ts_model_3 (TSModel)           (None, 180, 1, 1)    13101       []
#
#  ts_model_4 (TSModel)           (None, 720, 1, 1)    13101       []
#
# ==================================================================================================
# Total params: 26,202
# Trainable params: 13,101
# Non-trainable params: 13,101
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the time series model

# %%
timesnet.fit(train_dataset, val_dataset)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 8s 8s/step - loss: 8.9356 - mae: 9.8430 - PearsonCoef: 0.2586 - val_loss: 6.3347 - val_mae: 6.3347 - val_PearsonCoef: -0.0150
# Epoch 2/200
# 1/1 [==============================] - 8s 8s/step - loss: 7.8546 - mae: 8.6522 - PearsonCoef: 0.3657 - val_loss: 5.8445 - val_mae: 5.8445 - val_PearsonCoef: 0.2268
# Epoch 3/200
# 1/1 [==============================] - 8s 8s/step - loss: 7.0783 - mae: 7.7971 - PearsonCoef: 0.3819 - val_loss: 5.2392 - val_mae: 5.2392 - val_PearsonCoef: 0.4566
# Epoch 4/200
# 1/1 [==============================] - 8s 8s/step - loss: 6.3141 - mae: 6.9553 - PearsonCoef: 0.4082 - val_loss: 4.6488 - val_mae: 4.6488 - val_PearsonCoef: 0.6100
# Epoch 5/200
# 1/1 [==============================] - 8s 8s/step - loss: 5.0474 - mae: 5.5600 - PearsonCoef: 0.4744 - val_loss: 4.4919 - val_mae: 4.4919 - val_PearsonCoef: 0.6997
# Epoch 6/200
# 1/1 [==============================] - 8s 8s/step - loss: 4.4776 - mae: 4.9323 - PearsonCoef: 0.5212 - val_loss: 3.5498 - val_mae: 3.5498 - val_PearsonCoef: 0.7750
# Epoch 7/200
# 1/1 [==============================] - 8s 8s/step - loss: 4.0210 - mae: 4.4293 - PearsonCoef: 0.5198 - val_loss: 3.0980 - val_mae: 3.0980 - val_PearsonCoef: 0.8237
# Epoch 8/200
# 1/1 [==============================] - 8s 8s/step - loss: 3.5187 - mae: 3.8761 - PearsonCoef: 0.5218 - val_loss: 3.0127 - val_mae: 3.0127 - val_PearsonCoef: 0.8509
# Epoch 9/200
# 1/1 [==============================] - 8s 8s/step - loss: 3.0538 - mae: 3.3639 - PearsonCoef: 0.5471 - val_loss: 2.9808 - val_mae: 2.9808 - val_PearsonCoef: 0.8711
# Epoch 10/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.8451 - mae: 3.1340 - PearsonCoef: 0.5757 - val_loss: 2.6999 - val_mae: 2.6999 - val_PearsonCoef: 0.8907
# Epoch 11/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.6266 - mae: 2.8933 - PearsonCoef: 0.5881 - val_loss: 2.4200 - val_mae: 2.4200 - val_PearsonCoef: 0.9015
# Epoch 12/200
# 1/1 [==============================] - 16s 16s/step - loss: 2.5726 - mae: 2.8338 - PearsonCoef: 0.5844 - val_loss: 2.3137 - val_mae: 2.3137 - val_PearsonCoef: 0.9062
# Epoch 13/200
# 1/1 [==============================] - 18s 18s/step - loss: 2.4633 - mae: 2.7134 - PearsonCoef: 0.5874 - val_loss: 2.2560 - val_mae: 2.2560 - val_PearsonCoef: 0.9141
# Epoch 14/200
# 1/1 [==============================] - 17s 17s/step - loss: 2.1663 - mae: 2.3862 - PearsonCoef: 0.6047 - val_loss: 2.3843 - val_mae: 2.3843 - val_PearsonCoef: 0.9173
# Epoch 15/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.1275 - mae: 2.3436 - PearsonCoef: 0.6103 - val_loss: 2.1982 - val_mae: 2.1982 - val_PearsonCoef: 0.9224
# Epoch 16/200
# 1/1 [==============================] - 15s 15s/step - loss: 1.9769 - mae: 2.1777 - PearsonCoef: 0.5985 - val_loss: 2.0368 - val_mae: 2.0368 - val_PearsonCoef: 0.9236
# Epoch 17/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.8869 - mae: 2.0785 - PearsonCoef: 0.5931 - val_loss: 1.9900 - val_mae: 1.9900 - val_PearsonCoef: 0.9261
# Epoch 18/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.8445 - mae: 2.0318 - PearsonCoef: 0.5994 - val_loss: 2.0417 - val_mae: 2.0417 - val_PearsonCoef: 0.9277
# Epoch 19/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.7865 - mae: 1.9679 - PearsonCoef: 0.6033 - val_loss: 2.0139 - val_mae: 2.0139 - val_PearsonCoef: 0.9268
# Epoch 20/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.7079 - mae: 1.8813 - PearsonCoef: 0.5991 - val_loss: 1.9807 - val_mae: 1.9807 - val_PearsonCoef: 0.9293
# Epoch 21/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.6530 - mae: 1.8209 - PearsonCoef: 0.6004 - val_loss: 1.9381 - val_mae: 1.9381 - val_PearsonCoef: 0.9320
# Epoch 22/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.5833 - mae: 1.7441 - PearsonCoef: 0.6052 - val_loss: 1.8523 - val_mae: 1.8523 - val_PearsonCoef: 0.9335
# Epoch 23/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.5606 - mae: 1.7191 - PearsonCoef: 0.6027 - val_loss: 1.8300 - val_mae: 1.8300 - val_PearsonCoef: 0.9340
# Epoch 24/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.5281 - mae: 1.6832 - PearsonCoef: 0.6028 - val_loss: 1.9252 - val_mae: 1.9252 - val_PearsonCoef: 0.9337
# Epoch 25/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.4749 - mae: 1.6247 - PearsonCoef: 0.6110 - val_loss: 2.0290 - val_mae: 2.0290 - val_PearsonCoef: 0.9327
# Epoch 26/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.4773 - mae: 1.6273 - PearsonCoef: 0.6164 - val_loss: 1.9668 - val_mae: 1.9668 - val_PearsonCoef: 0.9321
# Epoch 27/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.4309 - mae: 1.5762 - PearsonCoef: 0.6128 - val_loss: 1.9371 - val_mae: 1.9371 - val_PearsonCoef: 0.9345
# Epoch 28/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3656 - mae: 1.5042 - PearsonCoef: 0.6164 - val_loss: 2.0028 - val_mae: 2.0028 - val_PearsonCoef: 0.9358
# Epoch 29/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3861 - mae: 1.5269 - PearsonCoef: 0.6198 - val_loss: 1.9281 - val_mae: 1.9281 - val_PearsonCoef: 0.9363
# Epoch 30/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3736 - mae: 1.5131 - PearsonCoef: 0.6134 - val_loss: 1.9517 - val_mae: 1.9517 - val_PearsonCoef: 0.9366
# Epoch 31/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2982 - mae: 1.4300 - PearsonCoef: 0.6171 - val_loss: 1.9500 - val_mae: 1.9500 - val_PearsonCoef: 0.9367
# Epoch 32/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3340 - mae: 1.4694 - PearsonCoef: 0.6219 - val_loss: 1.8468 - val_mae: 1.8468 - val_PearsonCoef: 0.9362
# Epoch 33/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3467 - mae: 1.4834 - PearsonCoef: 0.6126 - val_loss: 1.8214 - val_mae: 1.8214 - val_PearsonCoef: 0.9392
# Epoch 34/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2628 - mae: 1.3910 - PearsonCoef: 0.6188 - val_loss: 1.9045 - val_mae: 1.9045 - val_PearsonCoef: 0.9413
# Epoch 35/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3165 - mae: 1.4502 - PearsonCoef: 0.6219 - val_loss: 1.7812 - val_mae: 1.7812 - val_PearsonCoef: 0.9413
# Epoch 36/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.3044 - mae: 1.4369 - PearsonCoef: 0.6124 - val_loss: 1.7971 - val_mae: 1.7971 - val_PearsonCoef: 0.9423
# Epoch 37/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1911 - mae: 1.3121 - PearsonCoef: 0.6167 - val_loss: 1.9177 - val_mae: 1.9177 - val_PearsonCoef: 0.9421
# Epoch 38/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2980 - mae: 1.4298 - PearsonCoef: 0.6220 - val_loss: 1.8002 - val_mae: 1.8002 - val_PearsonCoef: 0.9408
# Epoch 39/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2786 - mae: 1.4084 - PearsonCoef: 0.6129 - val_loss: 1.8104 - val_mae: 1.8104 - val_PearsonCoef: 0.9433
# Epoch 40/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1668 - mae: 1.2853 - PearsonCoef: 0.6142 - val_loss: 1.9079 - val_mae: 1.9079 - val_PearsonCoef: 0.9448
# Epoch 41/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2876 - mae: 1.4184 - PearsonCoef: 0.6218 - val_loss: 1.7655 - val_mae: 1.7655 - val_PearsonCoef: 0.9451
# Epoch 42/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1744 - mae: 1.2936 - PearsonCoef: 0.6126 - val_loss: 1.7601 - val_mae: 1.7601 - val_PearsonCoef: 0.9447
# Epoch 43/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1465 - mae: 1.2629 - PearsonCoef: 0.6123 - val_loss: 1.8623 - val_mae: 1.8623 - val_PearsonCoef: 0.9437
# Epoch 44/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.2229 - mae: 1.3471 - PearsonCoef: 0.6221 - val_loss: 1.7928 - val_mae: 1.7928 - val_PearsonCoef: 0.9426
# Epoch 45/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1472 - mae: 1.2637 - PearsonCoef: 0.6159 - val_loss: 1.7171 - val_mae: 1.7171 - val_PearsonCoef: 0.9438
# Epoch 46/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1479 - mae: 1.2644 - PearsonCoef: 0.6149 - val_loss: 1.8285 - val_mae: 1.8285 - val_PearsonCoef: 0.9458
# Epoch 47/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1916 - mae: 1.3127 - PearsonCoef: 0.6237 - val_loss: 1.7369 - val_mae: 1.7369 - val_PearsonCoef: 0.9458
# Epoch 48/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0919 - mae: 1.2028 - PearsonCoef: 0.6194 - val_loss: 1.7329 - val_mae: 1.7329 - val_PearsonCoef: 0.9450
# Epoch 49/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0899 - mae: 1.2005 - PearsonCoef: 0.6168 - val_loss: 1.8253 - val_mae: 1.8253 - val_PearsonCoef: 0.9446
# Epoch 50/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1193 - mae: 1.2330 - PearsonCoef: 0.6243 - val_loss: 1.7944 - val_mae: 1.7944 - val_PearsonCoef: 0.9438
# Epoch 51/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0589 - mae: 1.1664 - PearsonCoef: 0.6190 - val_loss: 1.7367 - val_mae: 1.7367 - val_PearsonCoef: 0.9452
# Epoch 52/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0717 - mae: 1.1805 - PearsonCoef: 0.6173 - val_loss: 1.8179 - val_mae: 1.8179 - val_PearsonCoef: 0.9467
# Epoch 53/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.1337 - mae: 1.2489 - PearsonCoef: 0.6226 - val_loss: 1.7371 - val_mae: 1.7371 - val_PearsonCoef: 0.9459
# Epoch 54/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0418 - mae: 1.1476 - PearsonCoef: 0.6190 - val_loss: 1.7622 - val_mae: 1.7622 - val_PearsonCoef: 0.9450
# Epoch 55/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.0023 - mae: 1.1040 - PearsonCoef: 0.6200 - val_loss: 1.8334 - val_mae: 1.8334 - val_PearsonCoef: 0.9452

# %% [markdown]
# ## Forecast based on fitted model
# ***
#
# <font size=3>There are two forecasting modes: </font>
#
# 1. `multi-horizon` is used when 'fcst_horizon' defined in 'input_settings' is equal to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset)` to get the prediction.
#
# 2. `rolling` is used when 'fcst_horizon' defined in 'input_settings' is smaller to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset, rolling=True)` to get the prediction.

# %%
prediction['pred'] = timesnet.predict(fcst_dataset, rolling=True).flatten()
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fe0b46439e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method RevIN.call of <mammoth.networks.normalization.RevIN object at 0x7fe1136d5710>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Denormalize.call of <mammoth.networks.normalization.Denormalize object at 0x7fe0b3e4ed10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step

# %%
## Check the prediction accuracy
for key in data['series_key'].unique():
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(data[data['series_key']==key]['time_idx'],
             data[data['series_key']==key]['y'], label='Actual')
    plt.plot(prediction[prediction['series_key']==key]['time_idx'],
             prediction[prediction['series_key']==key]['pred'], label='Prediction')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.title(key)
    plt.show()
