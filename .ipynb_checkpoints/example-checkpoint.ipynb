# %%
from mammoth import *

# %% [markdown]
# ## I will build time series data by myself

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

seq_len = 1000
x = np.arange(seq_len)

series_1 = (np.log2(np.arange(seq_len)+1)+2*np.arange(seq_len)**0.5+
            4*np.sin(0.2*(x+1))+5*np.cos(x+12)+7*np.cos(0.04*(x-8))+
            np.random.random(seq_len)*5.5)
series_1 = pd.DataFrame({'series_key':['series_1']*seq_len, 
                         'time_idx':x,
                         'y':series_1,
                         'sin_wx':np.sin(0.2*(x+1)),
                         'cos_wx':np.cos(x+12)})

series_2 = (0.0002*(np.arange(seq_len)-400)**2+40+
            7*np.sin(0.5*(x+1))+10*np.cos(0.1*x)-4*np.cos(0.9*(x-20))+20*np.sin(0.02*(x+4))+
            np.random.random(seq_len)*5)
series_2 = pd.DataFrame({'series_key':['series_2']*seq_len, 
                         'time_idx':x,
                         'y':series_2,
                         'sin_wx':np.sin(0.02*(x+4)),
                         'cos_wx':np.cos(0.9*(x-20))})

series_3 = (np.log2(200-10*np.arange(seq_len)**0.2)**3/10+
            3*np.sin(0.05*(x-9))+2*np.sin(0.01*x)-np.cos(8*(x-10))-3*np.sin(0.2*(x+40))+
            np.random.random(seq_len)*4)
series_3 = pd.DataFrame({'series_key':['series_3']*seq_len, 
                         'time_idx':x,
                         'y':series_3,
                         'sin_wx':np.sin(0.01*x),
                         'cos_wx':np.cos(8*(x-10))})

data = pd.concat([series_1, series_2, series_3], ignore_index=True)
data['key_embed'] = data['series_key'].copy()

# %%
plt.figure(figsize=(10,4), dpi=100)
for key in data['series_key'].unique():
    plt.plot(data[data['series_key']==key]['y'].values, label=key)
plt.legend()
plt.grid(alpha=0.3)
plt.title('self-made time series')
plt.show()

# %% [markdown]
# # Build dataset for training and forecasting
# ***
#
# <font size=4>**dsbuilder** is the function to generate dataset for train, validation and forecast.</font>
#
# ***
# <font size=3>***input_settings*** is a dictionary contains the basic settings for preprocessing.</font>
#
# Required keys for 'input_settings' are as follows:
#
# * `seq_key` $<List/string/integer>$ The primary key of time series.
# * `seq_label` $<List/string/integer>$ The columns to identity the time sequence, such as calendar date or cumulative number.
# * `seq_target` $<List/string/integer>$ The target to predict.
# * `perc_horizon` $<integer>$ The size of looking back window, which means how long of historical data you will refer to.
# * `fcst_horizon` $<integer>$ The prediction length.
#
# Alternative keys for 'input_settings' are as follows:
# * `enc_feat` $<List>$ The name of features used in the encoding part. default: [].
# * `dec_feat` $<List>$ The name of features used in the decoding part. default: [].
# * `embed_feat` $<List>$ The name of embedding features. default: [].
# * `norm_feat` $<dictionary>$ The features you want to normalize. It is recommended to define 'norm_feat' within 'single_tsm' function. When you define 'norm_feat' here, there won't be trainable weights on mean and standard deviation. default: {}.
# * `min_avail_perc_rate` $<float>$ The minimum rate of padding time points verus perception horizon. When exceeded, the data at that time point will be padded. default: 0.25.
# * `min_avail_seq_rate` $<float>$ The minimum rate of padding time points verus each time series. Exceeded time series won't be trained. default: 0.5.
# * `window_freq` $<integer>$ The strides of sliding window to get time series pieces. default: 1.
# * `val_rate` $<float>$ The rate of validation part in train data. If None, no validation data will be built. default: None
#
# ***
# <font size=3>***train_settings*** is a dictionary contains the basic settings for training.</font>
#
# Alternative settings are as follows:
#
# * `optimizer` The optimizer function. It can either be a function in 'tensorflow.keras.optimizers' or the string representing the function. For detail, please refer to tensorflow.keras tutorial. default: 'adam'.
# * `learning_rate` default: 0.01.
# * `loss_func` It can be a python func(refer to tensorflow.keras tutorial for how to build self-defined Loss Function or string. Also it can be any iterable object(e.g. 'list' or 'tuple') containing different losses(e.g. ['mae','mse']). default: 'mae'.
# * `loss_weights` Same parameter in 'tensorflow.keras.model.Model.compile'. default: None.
# * `weighted_metrics` Same parameter in 'tensorflow.keras.model.Model.compile'. default: ['mae', PearsonCoef].
# * `batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 16.
# * `epochs` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1000.
# * `callbacks` Same parameter in 'tensorflow.keras.model.Model.fit'. For detail in defining your own callback functino, please refer to 'tensorflow.keras.callbacks'. default: [EarlyStopping(monitor='loss', patience=10)].
# * `verbose` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `validation_steps` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_freq` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `use_multiprocessing` Same parameter in 'tensorflow.keras.model.Model.fit'. Note that: 'multiprocessing' is not available when used GPU numbers < 2 or tensorflow version < 2.5.0. default: True.
# * `shuffle` Same parameter in 'tensorflow.keras.model.Model.fit'. default: True.
#
# ***
# Callable Arguments:
# * `train_data` $<pandas.DataFrame>$ The dataframe used for training.
# * `fcst_data` $<pandas.DataFrame>$ The dataframe used for forecasting.
# * `embed_data` $<pandas.DataFrame>$ The dataframe used for embedding.
#
# ***
# Return:
# * `train_dataset` $<tensorflow.data.Dataset>$ Dataset for training.
# * `val_dataset` $<tensorflow.data.Dataset>$ Dataset for validation.
# * `fcst_dataset` $<tensorflow.data.Dataset>$ Dataset for forecasting.
# * `input_settings` $<dictionary>$ Updated input_settings.
# * `prediction` $<pandas.DataFrame>$ The primary key frame of forecast, including seq_key and seq_label.

# %%
from tensorflow.keras.callbacks import EarlyStopping
from mammoth.losses import PearsonCoef
tf_ignore_warnings() ## Ignore warnings

## define input_settings
input_settings = {'seq_key':['series_key'],
                  'seq_label':['time_idx'],
                  'seq_target':['y'],
                  'perc_horizon':128,'fcst_horizon':1,
                  'enc_feat':['sin_wx', 'cos_wx'], 
                  'dec_feat':['sin_wx', 'cos_wx'], 
                  'embed_feat':['key_embed'], 'window_freq':1, 
                  'val_rate':0.2}

## define train_settings
train_settings = {'learning_rate':0.01, 'loss_func':'mae', 'batch_size':3,
                  'weighted_metrics':['mae',PearsonCoef],
                  'epochs':200, 'callbacks':[EarlyStopping(monitor='val_loss', patience=10)],
                  'use_multiprocessing':False}

train_data = data[data['time_idx']<=900]
fcst_data = data[data['time_idx']>900]
embed_data = data[input_settings['seq_key']+input_settings['embed_feat']].drop_duplicates()

## Use 'dsbuilder' to create datasets for training, validation and forecasting
train_dataset,\
val_dataset,\
fcst_dataset, \
input_settings, \
prediction = dsbuilder(input_settings)(train_data, fcst_data, embed_data)
# Out:
# /Users/diggerwang/Desktop/github/mammoth/mammoth/data_loader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['_count_'] = 1

# %% [markdown]
# ## Build time series models
# ***
#
# <font size=4>**signle_tsm** is the function to generate single time series model.</font>
#
# ***
# <font size=3>**Arguments**</font>
#
# ***input_settings*** \
# See the tutourials above.
#
# ***train_settings*** \
# See the tutourials above.
#
# ***embedding*** \
# A dictionary whose key is the method of embedding, normally string type, and value is also a dictionary which contains the hyperparameter for embedding(e.g. {'SimpleEmbedding':{'n_embed_layers':2}}).
# The builtin embedding is called 'SimpleEmbedding'. For customized embedding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'SimpleEmbedding':{}}.
#
# ***encoder*** \
# A dictionary whose key is the method of time series encoding, normally string type, and value is also a dictionary which contains the hyperparameter for encoding(e.g. {'WavenetEncoder':{'n_enc_filters':8, 'n_enc_layers':6}}).
# There are 4 builtin encoding methods:
# * `WavenetEncoder` -> https://arxiv.org/pdf/1609.03499v2.pdf
# * `TransformerEncoder` -> https://arxiv.org/pdf/1706.03762v5.pdf
# * `InformerEncoder` -> https://arxiv.org/pdf/2012.07436v3.pdf
# * `SciEncoder` -> https://arxiv.org/pdf/2106.09305v3.pdf
#
# For customized encoding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'WavenetEncoder':{}}.
#
# ***decoder*** \
# A dictionary whose key is the method of time series decoding, normally string type, and value is also a dictionary which contains the hyperparameter for decoding(e.g. {'DenseDecoder':{'dec_activation':'elu'}}).
# There are 2 builtin decoding methods:
# * `DenseDecoder` -> The most common decoding methods. Using fully connected layers after the encoder part to get decoder part.
# * `CaCtDecoder` -> https://arxiv.org/pdf/1711.11053v2.pdf
#
# For customized decoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'DenseDecoder':{}}.
#
# ***recoder*** \
# A dictionary whose key is the method of time series reverse encoding, normally string type, and value is also a dictionary which contains the hyperparameter for reverse encoding(e.g. {'ConvRecoder':{'n_rec_layers':2}}). Reverse encoding is used in multi-horizon forecasting. When you have enough future information and use them as the latent features, you can reverse encode the future information to its relative past time points.
# There are 1 builtin reverse encoding method:
# * `ConvRecoder` -> Use convolution to encode future information to now reversely.
#
# For customized reverse encoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'ConvRecoder':{}}.
#
# ***output*** \
# A dictionary whose key is the method of output, normally string type, and value is also a dictionary which contains the hyperparameter for output(e.g. {'MlpOutput':{'mlp_dims':[16,8]}}).
# There are 3 builtin output methods:
# * `MlpOutput` -> The most common output methods. Just use several fully connected layers to get the final output.
# * `AttentionOutput` -> The attention mechanism applied on the feature dimension. Usually used in attention-related models, e.g. Informer.
# * `TabnetOutput` -> Using TabNet for the final regression or classification. For TabNet, please refer to https://arxiv.org/pdf/1908.07442v5.pdf.
#
# ***is_fork*** \
# Whether use fork training. Fork training is only available to RNN-based and RNN-based models, e.g. 'WaveNet' and 'SCINet'. Fork training can save memory and speed up training process.
#
# ***norm_feat*** \
# A dictionary whose key is the normalization methods, and value is a iterable object that contains features you want to normalize. e.g. {'standard':['f1', 'f2']}. There are 4 normalization methods:
# * `standard`: $\frac{x-avg(x)}{std(x)}$
# * `minmax`: $\frac{x-min(x)}{max(x)-min(x)}$
# * `mean`: $\frac{x}{avg(x)}$
# * `maxabs`: $\frac{x}{max(abs(x))}$
#
# Note that: the target will be normalized using `RevIN` automatically. Thus you don't need to declare the target in 'norm_feat'. For `RevIN`, please refer to https://openreview.net/pdf?id=cGDAkQo1C0p. default: None.
#
# ***perc_horizon*** \
# The length of looking back window. If None, it will be the same with that defined in 'input_settings'. If not None, the value will replace the original 'perc_horizon' defined in 'input_settings'. default: None.
#
# ***
# <font size=3>**Return**</font>
#
# The untrained model with object type `ModelBase`

# %%
## Here take 'MTS-Mixer' as an example

mixer_g = single_tsm(input_settings, train_settings, 
                     embedding = {'FactorizedEmbedding':{'embed_out_dim':2}}, 
                     graph = {'GAT':{'graph_attn_layers':2}},
                     encoder = {'MixerEncoder':{'n_sub_seqs':8, 'temp_hidden_dims':16, 'channel_hidden_dims':4}}, 
                     decoder = {'DenseDecoder':{}}, 
                     recoder = None, 
                     output = {'MlpOutput':{'mlp_dims':[]}},
                     norm_feat = {'maxabs':['sin_wx','cos_wx']},
                     perc_horizon = 128,
                     is_y_affine = False,
                     is_feat_affine = False)
mixer_g.summary()
# Out:
# Model: "ts_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 721, 3)]     0           []
#
#  input_2 (InputLayer)           [(None, 721, 1)]     0           []
#
#  MovingWindowTransform_1 (Movin  ((None, 720, 129, 3  0          ['input_1[0][0]',
#  gWindowTransform)              ),                                'input_2[0][0]']
#                                  (None, 720, 129, 1
#                                 ))
#
#  TSInstanceNormalization_maxabs  (None, 720, 129, 3)  0          ['MovingWindowTransform_1[0][0]',
#  _1 (TSInstanceNormalization)                                     'MovingWindowTransform_1[0][1]']
#
#  SplitHisFut_1 (SplitHisFut)    ((None, 720, 128, 3  0           ['TSInstanceNormalization_maxabs_
#                                 ),                               1[0][0]',
#                                  (None, 720, 1, 2),               'MovingWindowTransform_1[0][1]']
#                                  (None, 720, 128, 1
#                                 ),
#                                  (None, 720, 1, 1))
#
#  RevIN_1 (RevIN)                ((None, 720, 128, 3  0           ['SplitHisFut_1[0][0]',
#                                 ),                                'SplitHisFut_1[0][2]']
#                                  (None, 720, 1, 1),
#                                  (None, 720, 1, 1))
#
#  encoder_input_multiply_masking  (None, 720, 128, 3)  0          ['RevIN_1[0][0]',
#  _1 (Multiply)                                                    'SplitHisFut_1[0][2]']
#
#  GAT_1 (GAT)                    ((None, 720, 128, 8  1064        ['encoder_input_multiply_masking_
#                                 ),                               1[0][0]']
#                                  (720, 128, 4, None
#                                 , None))
#
#  input_3 (InputLayer)           [(None, 1)]          0           []
#
#  MixerEncoder_1 (MixerEncoder)  (None, 720, 128, 4)  4152        ['GAT_1[0][0]']
#
#  FactorizedEmbedding_1 (Factori  (None, 2)           11          ['input_3[0][0]']
#  zedEmbedding)
#
#  slice_encoder_output_1 (Lambda  (None, 720, 128, 4)  0          ['MixerEncoder_1[0][0]']
#  )
#
#  expand_embed_input_dims_1 (Res  (None, 1, 1, 2)     0           ['FactorizedEmbedding_1[0][0]']
#  hape)
#
#  DenseDecoder_1 (DenseDecoder)  (None, 720, 1, 4)    128         ['slice_encoder_output_1[0][0]']
#
#  decoder_input_multiply_masking  (None, 720, 1, 2)   0           ['SplitHisFut_1[0][1]',
#  _1 (Multiply)                                                    'SplitHisFut_1[0][3]']
#
#  tf.tile (TFOpLambda)           (None, 720, 1, 2)    0           ['expand_embed_input_dims_1[0][0]
#                                                                  ']
#
#  concat_all_decoder_feats_1 (Co  (None, 720, 1, 8)   0           ['DenseDecoder_1[0][0]',
#  ncatenate)                                                       'decoder_input_multiply_masking_
#                                                                  1[0][0]',
#                                                                   'tf.tile[0][0]']
#
#  outlayer_input_multiply_maskin  (None, 720, 1, 8)   0           ['concat_all_decoder_feats_1[0][0
#  g_1 (Multiply)                                                  ]',
#                                                                   'SplitHisFut_1[0][3]']
#
#  MlpOutput_1 (MlpOutput)        (None, 720, 1, 1)    8           ['outlayer_input_multiply_masking
#                                                                  _1[0][0]']
#
#  denormalize (Denormalize)      (None, 720, 1, 1)    0           ['MlpOutput_1[0][0]',
#                                                                   'RevIN_1[0][1]',
#                                                                   'RevIN_1[0][2]']
#
#  output (Lambda)                (None, 720, 1, 1)    0           ['denormalize[0][0]']
#
#  ts_model_1 (TSModel)           (None, 180, 1, 1)    5363        []
#
# ==================================================================================================
# Total params: 10,726
# Trainable params: 5,363
# Non-trainable params: 5,363
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the time series model

# %%
mixer_g.fit(train_dataset, val_dataset)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 16.7004 - mae: 18.3963 - PearsonCoef: 0.1084 - val_loss: 10.9349 - val_mae: 10.9349 - val_PearsonCoef: -0.1698
# Epoch 2/200
# 1/1 [==============================] - 2s 2s/step - loss: 15.6371 - mae: 17.2250 - PearsonCoef: 0.1189 - val_loss: 10.2276 - val_mae: 10.2276 - val_PearsonCoef: -0.1768
# Epoch 3/200
# 1/1 [==============================] - 1s 1s/step - loss: 14.6859 - mae: 16.1772 - PearsonCoef: 0.1259 - val_loss: 9.6104 - val_mae: 9.6104 - val_PearsonCoef: -0.1870
# Epoch 4/200
# 1/1 [==============================] - 1s 1s/step - loss: 13.9972 - mae: 15.4186 - PearsonCoef: 0.1229 - val_loss: 9.2672 - val_mae: 9.2672 - val_PearsonCoef: -0.1995
# Epoch 5/200
# 1/1 [==============================] - 1s 1s/step - loss: 13.7088 - mae: 15.1009 - PearsonCoef: 0.1003 - val_loss: 9.0874 - val_mae: 9.0874 - val_PearsonCoef: -0.1982
# Epoch 6/200
# 1/1 [==============================] - 2s 2s/step - loss: 13.5856 - mae: 14.9652 - PearsonCoef: 0.0842 - val_loss: 8.9358 - val_mae: 8.9358 - val_PearsonCoef: -0.1897
# Epoch 7/200
200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5816 - mae: 1.7423 - PearsonCoef: 0.6089 - val_loss: 2.3522 - val_mae: 2.3522 - val_PearsonCoef: 0.8991
# Epoch 128/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.6223 - mae: 1.7870 - PearsonCoef: 0.6151 - val_loss: 2.2373 - val_mae: 2.2373 - val_PearsonCoef: 0.9001
# Epoch 129/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.6437 - mae: 1.8106 - PearsonCoef: 0.6046 - val_loss: 2.3730 - val_mae: 2.3730 - val_PearsonCoef: 0.9001
# Epoch 130/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5984 - mae: 1.7608 - PearsonCoef: 0.6159 - val_loss: 2.2616 - val_mae: 2.2616 - val_PearsonCoef: 0.9011
# Epoch 131/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5309 - mae: 1.6864 - PearsonCoef: 0.6093 - val_loss: 2.3167 - val_mae: 2.3167 - val_PearsonCoef: 0.9016
# Epoch 132/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5158 - mae: 1.6697 - PearsonCoef: 0.6118 - val_loss: 2.3079 - val_mae: 2.3079 - val_PearsonCoef: 0.9011
# Epoch 133/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5174 - mae: 1.6715 - PearsonCoef: 0.6137 - val_loss: 2.2466 - val_mae: 2.2466 - val_PearsonCoef: 0.9013
# Epoch 134/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5200 - mae: 1.6744 - PearsonCoef: 0.6089 - val_loss: 2.3802 - val_mae: 2.3802 - val_PearsonCoef: 0.9014
# Epoch 135/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5380 - mae: 1.6942 - PearsonCoef: 0.6168 - val_loss: 2.2280 - val_mae: 2.2280 - val_PearsonCoef: 0.9019
# Epoch 136/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5367 - mae: 1.6927 - PearsonCoef: 0.6071 - val_loss: 2.3595 - val_mae: 2.3595 - val_PearsonCoef: 0.9018
# Epoch 137/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5373 - mae: 1.6934 - PearsonCoef: 0.6177 - val_loss: 2.2273 - val_mae: 2.2273 - val_PearsonCoef: 0.9026
# Epoch 138/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5063 - mae: 1.6592 - PearsonCoef: 0.6093 - val_loss: 2.2889 - val_mae: 2.2889 - val_PearsonCoef: 0.9028
# Epoch 139/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4582 - mae: 1.6063 - PearsonCoef: 0.6154 - val_loss: 2.2699 - val_mae: 2.2699 - val_PearsonCoef: 0.9043
# Epoch 140/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4347 - mae: 1.5804 - PearsonCoef: 0.6133 - val_loss: 2.3096 - val_mae: 2.3096 - val_PearsonCoef: 0.9052
# Epoch 141/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4330 - mae: 1.5785 - PearsonCoef: 0.6160 - val_loss: 2.2379 - val_mae: 2.2379 - val_PearsonCoef: 0.9054
# Epoch 142/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4210 - mae: 1.5652 - PearsonCoef: 0.6134 - val_loss: 2.2943 - val_mae: 2.2943 - val_PearsonCoef: 0.9050
# Epoch 143/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4278 - mae: 1.5728 - PearsonCoef: 0.6171 - val_loss: 2.1856 - val_mae: 2.1856 - val_PearsonCoef: 0.9048
# Epoch 144/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4419 - mae: 1.5883 - PearsonCoef: 0.6098 - val_loss: 2.3339 - val_mae: 2.3339 - val_PearsonCoef: 0.9045
# Epoch 145/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4958 - mae: 1.6477 - PearsonCoef: 0.6196 - val_loss: 2.1830 - val_mae: 2.1830 - val_PearsonCoef: 0.9058
# Epoch 146/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5068 - mae: 1.6598 - PearsonCoef: 0.6083 - val_loss: 2.2893 - val_mae: 2.2893 - val_PearsonCoef: 0.9059
# Epoch 147/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4363 - mae: 1.5821 - PearsonCoef: 0.6187 - val_loss: 2.1943 - val_mae: 2.1943 - val_PearsonCoef: 0.9067
# Epoch 148/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3834 - mae: 1.5238 - PearsonCoef: 0.6129 - val_loss: 2.2572 - val_mae: 2.2572 - val_PearsonCoef: 0.9070
# Epoch 149/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3682 - mae: 1.5072 - PearsonCoef: 0.6163 - val_loss: 2.2196 - val_mae: 2.2196 - val_PearsonCoef: 0.9070
# Epoch 150/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3631 - mae: 1.5015 - PearsonCoef: 0.6156 - val_loss: 2.2173 - val_mae: 2.2173 - val_PearsonCoef: 0.9081
# Epoch 151/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3664 - mae: 1.5051 - PearsonCoef: 0.6139 - val_loss: 2.3103 - val_mae: 2.3103 - val_PearsonCoef: 0.9076
# Epoch 152/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4320 - mae: 1.5774 - PearsonCoef: 0.6210 - val_loss: 2.1329 - val_mae: 2.1329 - val_PearsonCoef: 0.9078
# Epoch 153/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5114 - mae: 1.6649 - PearsonCoef: 0.6073 - val_loss: 2.2251 - val_mae: 2.2251 - val_PearsonCoef: 0.9078
# Epoch 154/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3357 - mae: 1.4713 - PearsonCoef: 0.6173 - val_loss: 2.3088 - val_mae: 2.3088 - val_PearsonCoef: 0.9086
# Epoch 155/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3772 - mae: 1.5170 - PearsonCoef: 0.6206 - val_loss: 2.1361 - val_mae: 2.1361 - val_PearsonCoef: 0.9086
# Epoch 156/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5335 - mae: 1.6892 - PearsonCoef: 0.6070 - val_loss: 2.2307 - val_mae: 2.2307 - val_PearsonCoef: 0.9088
# Epoch 157/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3080 - mae: 1.4408 - PearsonCoef: 0.6174 - val_loss: 2.3468 - val_mae: 2.3468 - val_PearsonCoef: 0.9085
# Epoch 158/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4350 - mae: 1.5807 - PearsonCoef: 0.6235 - val_loss: 2.1330 - val_mae: 2.1330 - val_PearsonCoef: 0.9086
# Epoch 159/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5244 - mae: 1.6792 - PearsonCoef: 0.6071 - val_loss: 2.1566 - val_mae: 2.1566 - val_PearsonCoef: 0.9086
# Epoch 160/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3271 - mae: 1.4619 - PearsonCoef: 0.6132 - val_loss: 2.5003 - val_mae: 2.5003 - val_PearsonCoef: 0.9075
# Epoch 161/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.7074 - mae: 1.8807 - PearsonCoef: 0.6290 - val_loss: 2.2965 - val_mae: 2.2965 - val_PearsonCoef: 0.9094
# Epoch 162/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3741 - mae: 1.5136 - PearsonCoef: 0.6187 - val_loss: 2.0830 - val_mae: 2.0830 - val_PearsonCoef: 0.9085
# Epoch 163/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.6262 - mae: 1.7913 - PearsonCoef: 0.6027 - val_loss: 2.0897 - val_mae: 2.0897 - val_PearsonCoef: 0.9086
# Epoch 164/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.5195 - mae: 1.6738 - PearsonCoef: 0.6101 - val_loss: 2.3174 - val_mae: 2.3174 - val_PearsonCoef: 0.9100
# Epoch 165/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4394 - mae: 1.5856 - PearsonCoef: 0.6230 - val_loss: 2.3033 - val_mae: 2.3033 - val_PearsonCoef: 0.9108
# Epoch 166/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4550 - mae: 1.6028 - PearsonCoef: 0.6172 - val_loss: 2.1391 - val_mae: 2.1391 - val_PearsonCoef: 0.9101
# Epoch 167/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.3466 - mae: 1.4834 - PearsonCoef: 0.6115 - val_loss: 2.2017 - val_mae: 2.2017 - val_PearsonCoef: 0.9093
# Epoch 168/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4557 - mae: 1.6035 - PearsonCoef: 0.6180 - val_loss: 2.2476 - val_mae: 2.2476 - val_PearsonCoef: 0.9109
# Epoch 169/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.2694 - mae: 1.3983 - PearsonCoef: 0.6193 - val_loss: 2.1857 - val_mae: 2.1857 - val_PearsonCoef: 0.9104
# Epoch 170/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4680 - mae: 1.6171 - PearsonCoef: 0.6105 - val_loss: 2.2071 - val_mae: 2.2071 - val_PearsonCoef: 0.9097
# Epoch 171/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.2584 - mae: 1.3862 - PearsonCoef: 0.6159 - val_loss: 2.2536 - val_mae: 2.2536 - val_PearsonCoef: 0.9090
# Epoch 172/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4784 - mae: 1.6285 - PearsonCoef: 0.6199 - val_loss: 2.1140 - val_mae: 2.1140 - val_PearsonCoef: 0.9107

# %% [markdown]
# ## Forecast based on fitted model
# ***
#
# <font size=3>There are two forecasting modes: </font>
#
# 1. `multi-horizon` is used when 'fcst_horizon' defined in 'input_settings' is equal to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset)` to get the prediction.
#
# 2. `rolling` is used when 'fcst_horizon' defined in 'input_settings' is smaller to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset, rolling=True)` to get the prediction.

# %%
prediction['pred'] = mixer_g.predict(fcst_dataset, rolling=True).flatten()
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fba18c3ad40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method RevIN.call of <mammoth.networks.normalization.RevIN object at 0x7fba18c3e550>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Denormalize.call of <mammoth.networks.normalization.Denormalize object at 0x7fba18993f50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step

# %%
## Check the prediction accuracy
for key in data['series_key'].unique():
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(data[data['series_key']==key]['time_idx'],
             data[data['series_key']==key]['y'], label='Actual')
    plt.plot(prediction[prediction['series_key']==key]['time_idx'],
             prediction[prediction['series_key']==key]['pred'], label='Prediction')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.title(key)
    plt.show()

# %%
from tensorflow.keras import backend as K

ADJ_out = K.function(inputs = mixer_g.model.inputs, 
                     outputs = mixer_g.model.get_layer('GAT_1').output)

# %%
ADJ_out(train_dataset.batch(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8d905012adb9> in <module>
# ----> 1 ADJ_out(train_dataset.batch(3))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/backend.py in func(model_inputs)
#    4329     wrap_outputs = isinstance(outputs, list) and len(outputs) == 1
#    4330     def func(model_inputs):
# -> 4331       outs = model(model_inputs)
#    4332       if wrap_outputs:
#    4333         outs = [outs]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     195     # have a `shape` attribute.
#     196     if not hasattr(x, 'shape'):
# --> 197       raise TypeError(f'Inputs to a layer should be tensors. Got: {x}')
#     198
#     199   if len(inputs) != len(input_spec):
#
# TypeError: Inputs to a layer should be tensors. Got: <BatchDataset element_spec=((TensorSpec(shape=(None, 721, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.float64, name=None), TensorSpec(shape=(None, 721, 1), dtype=tf.float64, name=None)), TensorSpec(shape=(None, 720, 1, 1), dtype=tf.float64, name=None), TensorSpec(shape=(None, 720, 1, 1), dtype=tf.float64, name=None))>
