# %%
from mammoth import *
# Out:
# 2023-05-17 12:35:23.063478: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## I will build time series data by myself

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

seq_len = 1000
x = np.arange(seq_len)

series_1 = (np.log2(np.arange(seq_len)+1)+2*np.arange(seq_len)**0.5+
            4*np.sin(0.2*(x+1))+5*np.cos(x+12)+7*np.cos(0.04*(x-8))+
            np.random.random(seq_len)*5.5)
series_1 = pd.DataFrame({'series_key':['series_1']*seq_len, 
                         'time_idx':x,
                         'y':series_1,
                         'sin_wx':np.sin(0.2*(x+1)),
                         'cos_wx':np.cos(x+12)})

series_2 = (0.0002*(np.arange(seq_len)-400)**2+40+
            7*np.sin(0.5*(x+1))+10*np.cos(0.1*x)-4*np.cos(0.9*(x-20))+20*np.sin(0.02*(x+4))+
            np.random.random(seq_len)*5)
series_2 = pd.DataFrame({'series_key':['series_2']*seq_len, 
                         'time_idx':x,
                         'y':series_2,
                         'sin_wx':np.sin(0.02*(x+4)),
                         'cos_wx':np.cos(0.9*(x-20))})

series_3 = (np.log2(200-10*np.arange(seq_len)**0.2)**3/10+
            3*np.sin(0.05*(x-9))+2*np.sin(0.01*x)-np.cos(8*(x-10))-3*np.sin(0.2*(x+40))+
            np.random.random(seq_len)*4)
series_3 = pd.DataFrame({'series_key':['series_3']*seq_len, 
                         'time_idx':x,
                         'y':series_3,
                         'sin_wx':np.sin(0.01*x),
                         'cos_wx':np.cos(8*(x-10))})

data = pd.concat([series_1, series_2, series_3], ignore_index=True)
data['key_embed'] = data['series_key'].copy()

# %%
plt.figure(figsize=(10,4), dpi=100)
for key in data['series_key'].unique():
    plt.plot(data[data['series_key']==key]['y'].values, label=key)
plt.legend()
plt.grid(alpha=0.3)
plt.title('self-made time series')
plt.show()

# %% [markdown]
# # Build dataset for training and forecasting
# ***
#
# <font size=4>**dsbuilder** is the function to generate dataset for train, validation and forecast.</font>
#
# ***
# <font size=3>***input_settings*** is a dictionary contains the basic settings for preprocessing.</font>
#
# Required keys for 'input_settings' are as follows:
#
# * `seq_key` $<List/string/integer>$ The primary key of time series.
# * `seq_label` $<List/string/integer>$ The columns to identity the time sequence, such as calendar date or cumulative number.
# * `seq_target` $<List/string/integer>$ The target to predict.
# * `perc_horizon` $<integer>$ The size of looking back window, which means how long of historical data you will refer to.
# * `fcst_horizon` $<integer>$ The prediction length.
#
# Alternative keys for 'input_settings' are as follows:
# * `enc_feat` $<List>$ The name of features used in the encoding part. default: [].
# * `dec_feat` $<List>$ The name of features used in the decoding part. default: [].
# * `embed_feat` $<List>$ The name of embedding features. default: [].
# * `norm_feat` $<dictionary>$ The features you want to normalize. It is recommended to define 'norm_feat' within 'single_tsm' function. When you define 'norm_feat' here, there won't be trainable weights on mean and standard deviation. default: {}.
# * `min_avail_perc_rate` $<float>$ The minimum rate of padding time points verus perception horizon. When exceeded, the data at that time point will be padded. default: 0.25.
# * `min_avail_seq_rate` $<float>$ The minimum rate of padding time points verus each time series. Exceeded time series won't be trained. default: 0.5.
# * `window_freq` $<integer>$ The strides of sliding window to get time series pieces. default: 1.
# * `val_rate` $<float>$ The rate of validation part in train data. If None, no validation data will be built. default: None
#
# ***
# <font size=3>***train_settings*** is a dictionary contains the basic settings for training.</font>
#
# Alternative settings are as follows:
#
# * `optimizer` The optimizer function. It can either be a function in 'tensorflow.keras.optimizers' or the string representing the function. For detail, please refer to tensorflow.keras tutorial. default: 'adam'.
# * `learning_rate` default: 0.01.
# * `loss_func` It can be a python func(refer to tensorflow.keras tutorial for how to build self-defined Loss Function or string. Also it can be any iterable object(e.g. 'list' or 'tuple') containing different losses(e.g. ['mae','mse']). default: 'mae'.
# * `loss_weights` Same parameter in 'tensorflow.keras.model.Model.compile'. default: None.
# * `weighted_metrics` Same parameter in 'tensorflow.keras.model.Model.compile'. default: ['mae', PearsonCoef].
# * `batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 16.
# * `epochs` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1000.
# * `callbacks` Same parameter in 'tensorflow.keras.model.Model.fit'. For detail in defining your own callback functino, please refer to 'tensorflow.keras.callbacks'. default: [EarlyStopping(monitor='loss', patience=10)].
# * `verbose` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `validation_steps` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_batch_size` Same parameter in 'tensorflow.keras.model.Model.fit'. default: None.
# * `validation_freq` Same parameter in 'tensorflow.keras.model.Model.fit'. default: 1.
# * `use_multiprocessing` Same parameter in 'tensorflow.keras.model.Model.fit'. Note that: 'multiprocessing' is not available when used GPU numbers < 2 or tensorflow version < 2.5.0. default: True.
# * `shuffle` Same parameter in 'tensorflow.keras.model.Model.fit'. default: True.
#
# ***
# Callable Arguments:
# * `train_data` $<pandas.DataFrame>$ The dataframe used for training.
# * `fcst_data` $<pandas.DataFrame>$ The dataframe used for forecasting.
# * `embed_data` $<pandas.DataFrame>$ The dataframe used for embedding.
#
# ***
# Return:
# * `train_dataset` $<tensorflow.data.Dataset>$ Dataset for training.
# * `val_dataset` $<tensorflow.data.Dataset>$ Dataset for validation.
# * `fcst_dataset` $<tensorflow.data.Dataset>$ Dataset for forecasting.
# * `input_settings` $<dictionary>$ Updated input_settings.
# * `prediction` $<pandas.DataFrame>$ The primary key frame of forecast, including seq_key and seq_label.

# %%
from tensorflow.keras.callbacks import EarlyStopping
from mammoth.losses import PearsonCoef
tf_ignore_warnings() ## Ignore warnings

## define input_settings
input_settings = {'seq_key':['series_key'],
                  'seq_label':['time_idx'],
                  'seq_target':['y'],
                  'perc_horizon':64,'fcst_horizon':1,
                  'enc_feat':['sin_wx', 'cos_wx'], 
                  'dec_feat':['sin_wx', 'cos_wx'], 
                  'embed_feat':['key_embed'], 'window_freq':1, 
                  'verbose':'auto',
                  'val_rate':0.2}

## define train_settings
train_settings = {'learning_rate':0.01, 'loss_func':'mae', 'batch_size':3,
                  'weighted_metrics':['mae',PearsonCoef],
                  'epochs':200, 'callbacks':[EarlyStopping(monitor='val_loss', patience=10)],
                  'use_multiprocessing':False}

train_data = data[data['time_idx']<=900]
fcst_data = data[data['time_idx']>900]
embed_data = data[input_settings['seq_key']+input_settings['embed_feat']].drop_duplicates()

## Use 'dsbuilder' to create datasets for training, validation and forecasting
train_dataset,\
val_dataset,\
fcst_dataset, \
input_settings, \
prediction = dsbuilder(input_settings)(train_data, fcst_data, embed_data)
# Out:
# /Users/diggerwang/Desktop/github/mammoth/mammoth/data_loader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['_count_'] = 1
# /Users/diggerwang/Desktop/github/mammoth/mammoth/data_loader.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['_count_'] = 1

# %% [markdown]
# ## Build time series models
# ***
#
# <font size=4>**signle_tsm** is the function to generate single time series model.</font>
#
# ***
# <font size=3>**Arguments**</font>
#
# ***input_settings*** \
# See the tutourials above.
#
# ***train_settings*** \
# See the tutourials above.
#
# ***embedding*** \
# A dictionary whose key is the method of embedding, normally string type, and value is also a dictionary which contains the hyperparameter for embedding(e.g. {'SimpleEmbedding':{'n_embed_layers':2}}).
# The builtin embedding is called 'SimpleEmbedding'. For customized embedding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'SimpleEmbedding':{}}.
#
# ***encoder*** \
# A dictionary whose key is the method of time series encoding, normally string type, and value is also a dictionary which contains the hyperparameter for encoding(e.g. {'WavenetEncoder':{'n_enc_filters':8, 'n_enc_layers':6}}).
# There are 4 builtin encoding methods:
# * `WavenetEncoder` -> https://arxiv.org/pdf/1609.03499v2.pdf
# * `TransformerEncoder` -> https://arxiv.org/pdf/1706.03762v5.pdf
# * `InformerEncoder` -> https://arxiv.org/pdf/2012.07436v3.pdf
# * `SciEncoder` -> https://arxiv.org/pdf/2106.09305v3.pdf
#
# For customized encoding function, please refer to `mammoth.model.nn_blocks.ModelBlock`. default: {'WavenetEncoder':{}}.
#
# ***decoder*** \
# A dictionary whose key is the method of time series decoding, normally string type, and value is also a dictionary which contains the hyperparameter for decoding(e.g. {'DenseDecoder':{'dec_activation':'elu'}}).
# There are 2 builtin decoding methods:
# * `DenseDecoder` -> The most common decoding methods. Using fully connected layers after the encoder part to get decoder part.
# * `CaCtDecoder` -> https://arxiv.org/pdf/1711.11053v2.pdf
#
# For customized decoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'DenseDecoder':{}}.
#
# ***recoder*** \
# A dictionary whose key is the method of time series reverse encoding, normally string type, and value is also a dictionary which contains the hyperparameter for reverse encoding(e.g. {'ConvRecoder':{'n_rec_layers':2}}). Reverse encoding is used in multi-horizon forecasting. When you have enough future information and use them as the latent features, you can reverse encode the future information to its relative past time points.
# There are 1 builtin reverse encoding method:
# * `ConvRecoder` -> Use convolution to encode future information to now reversely.
#
# For customized reverse encoding function, please refer to mammoth.model.nn_blocks.ModelBlock. default: {'ConvRecoder':{}}.
#
# ***output*** \
# A dictionary whose key is the method of output, normally string type, and value is also a dictionary which contains the hyperparameter for output(e.g. {'MlpOutput':{'mlp_dims':[16,8]}}).
# There are 3 builtin output methods:
# * `MlpOutput` -> The most common output methods. Just use several fully connected layers to get the final output.
# * `AttentionOutput` -> The attention mechanism applied on the feature dimension. Usually used in attention-related models, e.g. Informer.
# * `TabnetOutput` -> Using TabNet for the final regression or classification. For TabNet, please refer to https://arxiv.org/pdf/1908.07442v5.pdf.
#
# ***is_fork*** \
# Whether use fork training. Fork training is only available to RNN-based and RNN-based models, e.g. 'WaveNet' and 'SCINet'. Fork training can save memory and speed up training process.
#
# ***norm_feat*** \
# A dictionary whose key is the normalization methods, and value is a iterable object that contains features you want to normalize. e.g. {'standard':['f1', 'f2']}. There are 4 normalization methods:
# * `standard`: $\frac{x-avg(x)}{std(x)}$
# * `minmax`: $\frac{x-min(x)}{max(x)-min(x)}$
# * `mean`: $\frac{x}{avg(x)}$
# * `maxabs`: $\frac{x}{max(abs(x))}$
#
# Note that: the target will be normalized using `RevIN` automatically. Thus you don't need to declare the target in 'norm_feat'. For `RevIN`, please refer to https://openreview.net/pdf?id=cGDAkQo1C0p. default: None.
#
# ***perc_horizon*** \
# The length of looking back window. If None, it will be the same with that defined in 'input_settings'. If not None, the value will replace the original 'perc_horizon' defined in 'input_settings'. default: None.
#
# ***
# <font size=3>**Return**</font>
#
# The untrained model with object type `ModelBase`

# %%
## Here take 'MTS-Mixer' as an example
TiDE = single_tsm(input_settings, train_settings, 
                 embedding = {'FactorizedEmbedding':{'embed_out_dim':2}}, 
                 graph = None,
                 encoder = {'TideEncoder':{'feat_proj_unit':2, 'enc_unit':4, 'enc_out_unit':4}}, 
                 decoder = {'DenseDecoder':{}}, 
                 recoder = None, 
                 output = {'MlpOutput':{'mlp_dims':[]}},
                 norm_feat = {'maxabs':['sin_wx','cos_wx']},
                 perc_horizon = 64)
TiDE.summary()
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Model: "ts_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 721, 3)]     0           []
#
#  input_2 (InputLayer)           [(None, 721, 1)]     0           []
#
#  MovingWindowTransform_1 (Movin  ((None, 720, 65, 3)  0          ['input_1[0][0]',
#  gWindowTransform)              , (None, 720, 65, 1               'input_2[0][0]']
#                                 ))
#
#  TSInstanceNormalization_maxabs  (None, 720, 65, 3)  4           ['MovingWindowTransform_1[0][0]',
#  _1 (TSInstanceNormalization)                                     'MovingWindowTransform_1[0][1]']
#
#  input_3 (InputLayer)           [(None, 1)]          0           []
#
#  SplitHisFut_1 (SplitHisFut)    ((None, 720, 64, 3)  0           ['TSInstanceNormalization_maxabs_
#                                 , (None, 720, 1, 2)              1[0][0]',
#                                 , (None, 720, 64, 1               'MovingWindowTransform_1[0][1]']
#                                 ),
#                                  (None, 720, 1, 1))
#
#  FactorizedEmbedding_1 (Factori  (None, 2)           11          ['input_3[0][0]']
#  zedEmbedding)
#
#  RevIN_1 (RevIN)                ((None, 720, 64, 3)  2           ['SplitHisFut_1[0][0]',
#                                 , (None, 720, 1, 1)               'SplitHisFut_1[0][2]']
#                                 , (None, 720, 1, 1)
#                                 )
#
#  expand_embed_input_dims_1 (Res  (None, 1, 1, 2)     0           ['FactorizedEmbedding_1[0][0]']
#  hape)
#
#  encoder_input_multiply_masking  (None, 720, 64, 3)  0           ['RevIN_1[0][0]',
#  _1 (Multiply)                                                    'SplitHisFut_1[0][2]']
#
#  tf.tile (TFOpLambda)           (None, 720, 64, 2)   0           ['expand_embed_input_dims_1[0][0]
#                                                                  ']
#
#  concat_embed_features_1 (Conca  (None, 720, 64, 5)  0           ['encoder_input_multiply_masking_
#  tenate)                                                         1[0][0]',
#                                                                   'tf.tile[0][0]']
#
#  TideEncoder_1 (TideEncoder)    (None, 720, 64, 4)   268478      ['concat_embed_features_1[0][0]']
#
#  slice_encoder_output_1 (Lambda  (None, 720, 64, 4)  0           ['TideEncoder_1[0][0]']
#  )
#
#  DenseDecoder_1 (DenseDecoder)  (None, 720, 1, 4)    64          ['slice_encoder_output_1[0][0]']
#
#  decoder_input_multiply_masking  (None, 720, 1, 2)   0           ['SplitHisFut_1[0][1]',
#  _1 (Multiply)                                                    'SplitHisFut_1[0][3]']
#
#  concat_all_decoder_feats_1 (Co  (None, 720, 1, 6)   0           ['DenseDecoder_1[0][0]',
#  ncatenate)                                                       'decoder_input_multiply_masking_
#                                                                  1[0][0]']
#
#  outlayer_input_multiply_maskin  (None, 720, 1, 6)   0           ['concat_all_decoder_feats_1[0][0
#  g_1 (Multiply)                                                  ]',
#                                                                   'SplitHisFut_1[0][3]']
#
#  MlpOutput_1 (MlpOutput)        (None, 720, 1, 1)    6           ['outlayer_input_multiply_masking
#                                                                  _1[0][0]']
#
#  denormalize (Denormalize)      (None, 720, 1, 1)    0           ['MlpOutput_1[0][0]',
#                                                                   'RevIN_1[0][1]',
#                                                                   'RevIN_1[0][2]']
#
#  output (Lambda)                (None, 720, 1, 1)    0           ['denormalize[0][0]']
#
#  ts_model_1 (TSModel)           (None, 180, 1, 1)    268565      []
#
# ==================================================================================================
# Total params: 537,130
# Trainable params: 268,565
# Non-trainable params: 268,565
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the time series model

# %%
TiDE.fit(train_dataset, val_dataset)
# Out:
# 2023-05-17 12:38:31.604192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:31.604899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:31.609454: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:786] AUTO sharding policy will apply DATA sharding policy as it failed to apply FILE sharding policy because of the following reason: Found an unshardable source dataset: name: "TensorSliceDataset/_1"
# op: "TensorSliceDataset"
# input: "Placeholder/_0"
# attr {
#   key: "Toutput_types"
#   value {
#     list {
#       type: DT_DOUBLE
#     }
#   }
# }
# attr {
#   key: "_cardinality"
#   value {
#     i: 3
#   }
# }
# attr {
#   key: "is_files"
#   value {
#     b: false
#   }
# }
# attr {
#   key: "metadata"
#   value {
#     s: "\n\024TensorSliceDataset:0"
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 721
#         }
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "replicate_on_split"
#   value {
#     b: false
#   }
# }
# experimental_type {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_DATASET
#     args {
#       type_id: TFT_PRODUCT
#       args {
#         type_id: TFT_TENSOR
#         args {
#           type_id: TFT_DOUBLE
#         }
#       }
#     }
#   }
# }
#
# 2023-05-17 12:38:31.625793: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:31.626322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:31.686147: W tensorflow/core/framework/dataset.cc:807] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2023-05-17 12:38:31.686613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:31.709975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:31.710446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_7}}]]
# Epoch 1/200
# 2023-05-17 12:38:31.957784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.3332 - mae: 3.4901 - PearsonCoef: 0.6631
# 2023-05-17 12:38:32.621349: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:32.716530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:32.739641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:32.826267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.3332 - mae: 3.4901 - PearsonCoef: 0.6631 - val_loss: 3.2050 - val_mae: 3.2050 - val_PearsonCoef: 0.8487
# Epoch 2/200
# 2023-05-17 12:38:33.059034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:33.059498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:33.117458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.3241 - mae: 3.4806 - PearsonCoef: 0.6618
# 2023-05-17 12:38:33.779432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,244,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:33.869996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:33.892252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,244,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:33.981827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.3241 - mae: 3.4806 - PearsonCoef: 0.6618 - val_loss: 3.1492 - val_mae: 3.1492 - val_PearsonCoef: 0.8523
# Epoch 3/200
# 2023-05-17 12:38:34.228080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:34.228594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:34.285788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.2606 - mae: 3.4141 - PearsonCoef: 0.6692
# 2023-05-17 12:38:34.977247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:35.071367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:35.094839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:35.184456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.2606 - mae: 3.4141 - PearsonCoef: 0.6692 - val_loss: 3.0998 - val_mae: 3.0998 - val_PearsonCoef: 0.8553
# Epoch 4/200
# 2023-05-17 12:38:35.425997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:35.426506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:35.484573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.2581 - mae: 3.4115 - PearsonCoef: 0.6713
# 2023-05-17 12:38:36.136993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,244,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:36.225294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:36.246648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,244,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:36.322413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.2581 - mae: 3.4115 - PearsonCoef: 0.6713 - val_loss: 3.0852 - val_mae: 3.0852 - val_PearsonCoef: 0.8576
# Epoch 5/200
# 2023-05-17 12:38:36.541458: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:36.541899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:36.594176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.1953 - mae: 3.3458 - PearsonCoef: 0.6724
# 2023-05-17 12:38:37.223480: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:37.304468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:37.325663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:37.413488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.1953 - mae: 3.3458 - PearsonCoef: 0.6724 - val_loss: 3.0840 - val_mae: 3.0840 - val_PearsonCoef: 0.8597
# Epoch 6/200
# 2023-05-17 12:38:37.646843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:37.647302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:37.703810: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.1938 - mae: 3.3441 - PearsonCoef: 0.6678
# 2023-05-17 12:38:38.382308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:38.470956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:38.505813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:38.598471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.1938 - mae: 3.3441 - PearsonCoef: 0.6678 - val_loss: 3.0262 - val_mae: 3.0262 - val_PearsonCoef: 0.8623
# Epoch 7/200
# 2023-05-17 12:38:38.837425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:38.837966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:38.896727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.1300 - mae: 3.2773 - PearsonCoef: 0.6727
# 2023-05-17 12:38:39.560014: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:39.647732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:39.669771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:39.746800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.1300 - mae: 3.2773 - PearsonCoef: 0.6727 - val_loss: 2.9612 - val_mae: 2.9612 - val_PearsonCoef: 0.8650
# Epoch 8/200
# 2023-05-17 12:38:39.977597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:39.978106: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:40.029073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.1297 - mae: 3.2771 - PearsonCoef: 0.6743
# 2023-05-17 12:38:40.671138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:40.756042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:40.777206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:40.852681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.1297 - mae: 3.2771 - PearsonCoef: 0.6743 - val_loss: 2.9347 - val_mae: 2.9347 - val_PearsonCoef: 0.8672
# Epoch 9/200
# 2023-05-17 12:38:41.075703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:41.076208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,721,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:41.130890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.0697 - mae: 3.2143 - PearsonCoef: 0.6755
# 2023-05-17 12:38:41.770574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,244,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:41.864954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:41.886076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype double and shape [3,244,3]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:41.962443: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - 1s 1s/step - loss: 3.0697 - mae: 3.2143 - PearsonCoef: 0.6755 - val_loss: 2.9455 - val_mae: 2.9455 - val_PearsonCoef: 0.8690
# Epoch 10/200
# 2023-05-17 12:38:42.187323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype double and shape [3,721,1]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-17 12:38:42.187755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_10' with dtype double and shape [3,720,1]
# 	 [[{{node Placeholder/_10}}]]
# 2023-05-17 12:38:42.244248: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 1/1 [==============================] - ETA: 0s - loss: 3.0864 - mae: 3.2317 - PearsonCoef: 0.6669
# 2023-05-17 12:38:42.918378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_7' with dtype double and shape [3,180,1]
# 	 [[{{node Placeholder/_7}}]]
# 2023-05-17 12:38:43.005696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-17 12:38:43.027755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype double and shape [3,1]
# 	 [[{{node Placeholder/_2}}]]
# 2023-05-17 12:38:43.109422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype variant
# 	 [[{{node Placeholder/_0}}]]

# %% [markdown]
# ## Forecast based on fitted model
# ***
#
# <font size=3>There are two forecasting modes: </font>
#
# 1. `multi-horizon` is used when 'fcst_horizon' defined in 'input_settings' is equal to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset)` to get the prediction.
#
# 2. `rolling` is used when 'fcst_horizon' defined in 'input_settings' is smaller to the real future length you want to give prediction. You can call `transformer.predict(fcst_dataset, rolling=True)` to get the prediction.

# %%
prediction['pred'] = TiDE.predict(fcst_dataset, rolling=True).flatten()
# Out:
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f88224f44d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method RevIN.call of <mammoth.networks.normalization.RevIN object at 0x7f88224b0e90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Denormalize.call of <mammoth.networks.normalization.Denormalize object at 0x7f87fe5c6b50>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 85ms/step

# %%
## Check the prediction accuracy
for key in data['series_key'].unique():
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(data[data['series_key']==key]['time_idx'],
             data[data['series_key']==key]['y'], label='Actual')
    plt.plot(prediction[prediction['series_key']==key]['time_idx'],
             prediction[prediction['series_key']==key]['pred'], label='Prediction')
    plt.legend()
    plt.grid(alpha=0.3)
    plt.title(key)
    plt.show()
